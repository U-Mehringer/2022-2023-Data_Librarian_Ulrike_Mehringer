# %% [markdown]
# ## Numpy example

# %%
import numpy as np

# %%
x = np.random.normal(size=100)

# %%
x.reshape((20,5))
# Out:
# array([[ 0.49489934,  0.53001938,  0.8623055 ,  0.29603781, -1.36630796],
#        [-0.5895831 ,  0.11565024,  1.17690046, -0.31415619, -1.88066167],
#        [-0.24286751,  1.40797388, -2.70419826, -0.99147429,  0.21381235],
#        [-0.04857457,  0.1138723 , -0.64868096,  0.04410144,  0.78293971],
#        [ 0.28732835, -1.7976653 ,  0.40052091, -0.23601461,  2.10402158],
#        [-0.41191828, -0.10563017, -0.24672225, -0.33006937, -0.23394117],
#        [ 0.84350809, -2.10951538, -0.08049432,  1.33409582,  0.58395653],
#        [ 0.47277128, -0.9011548 , -0.80601392, -0.59438404, -1.23825802],
#        [ 2.54918559, -0.11281096, -1.04748599,  0.67367752,  1.65408557],
#        [-1.26983874, -1.30949557,  0.15048735,  0.21594263, -0.30020242],
#        [-0.61910478,  0.37159958, -1.02488738, -1.47872104,  0.53833812],
#        [-1.47774103,  0.16708313,  0.6272931 ,  0.62570217,  0.18583218],
#        [-1.26891857,  0.35863233,  0.34141465, -0.46629257, -0.87299746],
# ...

# %%
x.dot(x.T)
# Out:
# 84.85993701229745
