# %% [markdown]
# ## 3.6 Symmetrie und Schiefe

# %% [markdown]
# ## 3.7 Ausreißer III

# %% [markdown]
# ### Aufgabe 3.6

# %% [markdown]
# Abb. 1: symmetrisch, bimodal
#
# Abb. 2: linksschief, unimodal
#
# Abb. 3: linksschief, unimodal
#
# Abb. 4: rechtsschief, unimodal
#
# Abb. 5: symmetrisch, gleichverteilt
#
# Abb. 6: linksschief, unimodal
#
# Abb. 7: rechtsschief, unimodal
#
# Abb. 8: rechtsschief, unimodal
#
# Abb. 9: symmetrisch, unimodal

# %% [markdown]
# ### Aufgabe 3.7

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set()
df = pd.read_csv("../data/Library_Usage.csv")

# %%
df['Total Checkouts Sqrt'] = df['Total Checkouts']**(0.5)
sns.displot(df['Total Checkouts Sqrt'],kde=False)

# %% [markdown]
# #### Schöner Aufsatz über Ausreißer: http://statistik.rw.fau.de/files/2016/03/d0009.pdf
# Extremwerte müssen keine Ausreißer sein.

# %% [markdown]
# ### Beispiele aus dem Skript

# %%
import pandas as pd
import seaborn as sns
#%matplotlib inline
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv("../data/Library_Usage.csv")
sns.displot(df['Total Checkouts'],kde=False)
