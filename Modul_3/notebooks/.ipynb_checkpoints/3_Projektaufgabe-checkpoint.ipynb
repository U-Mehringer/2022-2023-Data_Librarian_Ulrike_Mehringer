# %% [markdown]
# # 3. Projektaufgabe

# %%
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# Library_Usage_Clean: Zeilen mit NaN sind entfernt
df = pd.read_csv('../data/Library_Usage_Clean.csv')

# Entfernung der oberen 1,5% Ausreißer von Total Checkouts
df_spike = df.drop(df[df['Total Checkouts']>1961.0].index)

# davon Entfernung aller Null-Ausleihen
# BenutzerInnen mit Ausleihen und BenutzerInnen mit 0 Ausleihen werden getrennt betrachtet
df_nullis = df_spike.drop(df_spike[df_spike['Total Checkouts']==0.0].index)

# %% [markdown]
# ## Wie setzt sich die Kundschaft mit null Ausleihen zusammen?

# %%
# row_filter_null = (df['Total Checkouts'] == 0.0)
# df_null = df.loc[row_filter_null]
# df_nullis.info()

# %% [markdown]
# ## Wieviel Prozent der Kunden sind Senioren und Kinder/Jugendliche?

# %%
df = df_nullis

# %%
row_filter1 = (df['Age Range'] == '65 to 74 years') | (df['Age Range'] =='75 years and over')
senioren = len(df.loc[row_filter1])*100/len(df)

row_filter2 = (df['Age Range'] == '0 to 9 years') | (df['Age Range'] == '10 to 19 years')
kinder = len(df.loc[row_filter2])*100/len(df)


print(round(senioren,2),"Prozent der Kunden sind Senioren ab 65 Jahren,",round(kinder,2),"Prozent sind Kinder und Jugendliche bis 19 Jahre.")
# Out:
# 11.97 Prozent der Kunden sind Senioren ab 65 Jahren, 23.97 Prozent sind Kinder und Jugendliche bis 19 Jahre.

# %%
alle = len(df)
df_alter = df['Age Range']
s = df_alter.value_counts()*100/alle
plt.pie(s,labels=(round(s,2)))
plt.legend(s.index,bbox_to_anchor=(1.1,0.9),loc='upper left')
plt.title('BenutzerInnen nach Altersgruppen in Prozent',fontsize=22,loc='left')
plt.figure()

# %%
order = ['0 to 9 years','10 to 19 years','20 to 24 years','25 to 34 years','35 to 44 years','45 to 54 years','55 to 59 years','60 to 64 years','65 to 74 years','75 years and over']
sns.catplot(y='Age Range',data=df,kind='count',color='steelblue',order=order)
plt.title('Anzahl der BenutzerInnen nach Altersgruppen',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Anzahl der BenutzerInnen nach Altersgruppen')

# %% [markdown]
# ## Wieviele Ausleihen tätigen die einzelnen Altersgruppen?

# %%
order = ['0 to 9 years','10 to 19 years','20 to 24 years','25 to 34 years','35 to 44 years','45 to 54 years','55 to 59 years','60 to 64 years','65 to 74 years','75 years and over']
sns.barplot(data=df,y='Age Range',x='Total Checkouts',order=order,palette='flare')
#plt.xticks(rotation=90)
plt.title('Anzahl der Ausleihen nach Altersgruppen',fontsize=20,loc='right')
plt.figure()

# %% [markdown]
# ## Wieviele Nutzer möchten per Email benachrichtig werden?

# %%
row_filter_email = (df['Notice Preference Definition'] == 'Email')
row_filter_post = (df['Notice Preference Definition'] == 'Print')
row_filter_phone = (df['Notice Preference Definition'] == 'Phone')
email = len(df.loc[row_filter_email])*100/len(df)
post = len(df.loc[row_filter_post])*100/len(df)
phone = len(df.loc[row_filter_phone])*100/len(df)

print(round(email,2),"Prozent der BenutzerInnen bevorzugen Email,",round(post,2),"Prozent möchten per Post benachrichtigt werden, und ",round(phone,2),"Prozent möchten per Telefon informiert werden.")
# Out:
# 89.41 Prozent der BenutzerInnen bevorzugen Email, 1.35 Prozent möchten per Post benachrichtigt werden, und  8.98 Prozent möchten per Telefon informiert werden.

# %%
sns.catplot(y='Age Range',hue='Notice Preference Definition',data=df,kind='count',order=order,height=7,aspect=1.5)

# %% [markdown]
# ## Wie alt sind diese Nutzer im Durchschnitt im Vergleich zu denen, die per Post informiert werden möchten?

# %%
age_mean_df = pd.crosstab(df['Age Range'],df['Notice Preference Definition'],margins=True)
age_mean_df
# Out:
# Notice Preference Definition   Email  None  Phone  Print     All
# Age Range
# 0 to 9 years                   17853   218   1640    383   20094
# 10 to 19 years                 40818   132   8183    484   49617
# 20 to 24 years                 14146    51   1852    216   16265
# 25 to 34 years                 53283   116   2046    580   56025
# 35 to 44 years                 51625   103   1871    545   54144
# 45 to 54 years                 32488    57   1841    385   34771
# 55 to 59 years                 11946    24   1107    202   13279
# 60 to 64 years                 10276    30   1342    221   11869
# 65 to 74 years                 17639    29   3122    485   21275
# 75 years and over               9981    28   3108    414   13531
# All                           260055   788  26112   3915  290870

# %%
email_df = df.loc[row_filter_email]
post_df = df.loc[row_filter_post]
phone_df = df.loc[row_filter_phone]
email_df = email_df.rename(columns={'Age Range':'Email'})
post_df = post_df.rename(columns={'Age Range':'Print'})
phone_df = phone_df.rename(columns={'Age Range':'Phone'})
                           
e = email_df['Email'].value_counts()
p = post_df['Print'].value_counts()
t = phone_df['Phone'].value_counts()

age_df = pd.concat([e,p,t],axis=1)
age_df = age_df.rename_axis('Age Range').reset_index()
age_df = age_df.sort_values(by=['Age Range'])

age_df['Age Mean'] = [(0+9)/2,(10+19)/2,(20+24)/2,(25+34)/2,(35+44)/2,(45+54)/2,(55+59)/2,(60+64)/2,(65+74)/2,77.0]
age_df['Age Email'] = age_df['Email']*age_df['Age Mean']
age_df['Age Print'] = age_df['Print']*age_df['Age Mean']

age_df
# Out:
#            Age Range  Email  Print  Phone  Age Mean  Age Email  Age Print
# 4       0 to 9 years  17853    383   1640       4.5    80338.5     1723.5
# 2     10 to 19 years  40818    484   8183      14.5   591861.0     7018.0
# 6     20 to 24 years  14146    216   1852      22.0   311212.0     4752.0
# 0     25 to 34 years  53283    580   2046      29.5  1571848.5    17110.0
# 1     35 to 44 years  51625    545   1871      39.5  2039187.5    21527.5
# 3     45 to 54 years  32488    385   1841      49.5  1608156.0    19057.5
# 7     55 to 59 years  11946    202   1107      57.0   680922.0    11514.0
# 8     60 to 64 years  10276    221   1342      62.0   637112.0    13702.0
# 5     65 to 74 years  17639    485   3122      69.5  1225910.5    33707.5
# 9  75 years and over   9981    414   3108      77.0   768537.0    31878.0

# %%
alter_email = age_df['Age Email'].sum()/age_df['Email'].sum()
alter_post = age_df['Age Print'].sum()/age_df['Print'].sum()

print ("Menschen, die per Email benachrichtigt werden wollen, sind durchschnittlich",alter_email,'Jahre alt. Personen mit Postbenachrichtigung sind durchschnittlich',alter_post,'Jahre alt.')
# Out:
# Menschen, die per Email benachrichtigt werden wollen, sind durchschnittlich 36.588740843283155 Jahre alt. Personen mit Postbenachrichtigung sind durchschnittlich 41.37675606641124 Jahre alt.

# %%
sns.relplot(x='Email',y='Phone',hue='Age Range',data=age_df)

# %% [markdown]
# ## Wieviele Ausleihen werden im Mittel pro Altersgruppe und pro Jahr getätigt?

# %% [markdown]
# ## Leihen ältere Bibliothekskunden im Schnitt mehr Bücher aus als jüngere?

# %% [markdown]
# ## Führen Kunden, die häufiger Ausleihen tätigen, im Schnitt auch häufiger Verlängerungen durch?

# %% [markdown]
# ## Nimmt die Anzahl der Ausleihen mit zunehmender Dauer der Mitgliedschaft ab?
