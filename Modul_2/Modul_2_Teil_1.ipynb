# %% [markdown]
# # Modul 2, Teil 1

# %%
import pandas as pd
import urllib.request
import urllib.parse
import json

# %%
# Daten einlesen und in der Datei botanik.json ablegen
url = "https://www.bibsonomy.org/json/search/botanik?items=1000&duplicates=merged"
botanik = "botanik.json"
urllib.request.urlretrieve(url,botanik)
# Out:
# ('botanik.json', <http.client.HTTPMessage at 0x7f2595ba99d0>)

# %%
# Datei zum Lesen öffnen
with open('botanik.json','r') as botanik_infile:
    data = botanik_infile.readlines()

# %%
type(data)
# Out:
# list

# %%
list(data)
# Out:
# ['\n',
#  '{  \n',
#  '   "types" : {\n',
#  '      "Bookmark" : {\n',
#  '         "pluralLabel" : "Bookmarks"\n',
#  '      },\n',
#  '      "Publication" : {\n',
#  '         "pluralLabel" : "Publications"\n',
#  '      },\n',
#  '      "GoldStandardPublication" : {\n',
#  '         "pluralLabel" : "GoldStandardPublications"\n',
#  '      },\n',
#  '      "GoldStandardBookmark" : {\n',
#  '         "pluralLabel" : "GoldStandardBookmarks"\n',
#  '      },\n',
#  '      "Tag" : {\n',
#  '         "pluralLabel" : "Tags"\n',
#  '      },\n',
#  '      "User" : {\n',
#  '         "pluralLabel" : "Users"\n',
#  '      },\n',
#  '      "Sphere" : {\n',
#  '         "pluralLabel" : "Spheres"\n',
#  '      }\n',
#  '   },\n',
#  '   \n',
#  '   "properties" : {\n',
#  '      "count" : {\n',
#  '         "valueType" : "number"\n',
#  '      },\n',
#  '      "date" : {\n',
#  '         "valueType" : "date"\n',
#  '      },\n',
#  '      "changeDate" : {\n',
#  '         "valueType" : "date"\n',
#  '      },\n',
#  '      "url" : {\n',
#  '         "valueType" : "url"\n',
#  '      },\n',
#  '      "id" : {\n',
#  '         "valueType" : "url"\n',
#  '      },\n',
#  '      "tags" : {\n',
#  '         "valueType" : "item"\n',
#  '      },\n',
#  '      "user" : {\n',
#  '         "valueType" : "item"\n',
#  '      }      \n',
#  '   },\n',
#  '   \n',
#  '   "items" : [\n',
#  '   \t  \n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/151a9bb7aadbb8f9cd7516d287ef842a/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "from_android"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "151a9bb7aadbb8f9cd7516d287ef842a",\n',
#  '         "label" : "Weiden (Botanik) \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-06-02 23:46:33",\n',
#  '         "changeDate" : "2017-06-02 23:46:33",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Weiden_(Botanik)"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/279da9197ac94560b25d4fad31e097b0/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "from_android"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "279da9197ac94560b25d4fad31e097b0",\n',
#  '         "label" : "Horst (Botanik) \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2018-05-01 18:28:10",\n',
#  '         "changeDate" : "2018-05-01 18:28:10",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.wikipedia.org/wiki/Horst_(Botanik)"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/6c693298cf621782f51ed684a92a576e/karinnadrowski",\n',
#  '         "tags" : [\n',
#  '            "spezbot","botanik","spezielle"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "6c693298cf621782f51ed684a92a576e",\n',
#  '         "label" : "Spezielle Botanik und funktionelle Biodiversität",\n',
#  '         "user" : "karinnadrowski",\n',
#  '         "description" : "",\n',
#  '         "date" : "2011-02-13 13:47:31",\n',
#  '         "changeDate" : "2011-02-13 13:47:31",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://alfresco.uni-leipzig.de/spezbot/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/eb7eebfa272a71cc44009253bcecfed2/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "from_android"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "eb7eebfa272a71cc44009253bcecfed2",\n',
#  '         "label" : "Botanik - Wüstenpflanze erntet Wasser aus der Luft - Wissen - Süddeutsche.de",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2018-05-07 09:40:28",\n',
#  '         "changeDate" : "2018-05-07 09:40:28",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.sueddeutsche.de/wissen/botanik-wuestenpflanze-erntet-wasser-aus-der-luft-1.3021848"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/fa8e601741b670106589bbd019a32b5a/robingarcia",\n',
#  '         "tags" : [\n',
#  '            "Unsortierte_Lesezeichen"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "fa8e601741b670106589bbd019a32b5a",\n',
#  '         "label" : "Geschichte der Botanik - Springer",\n',
#  '         "user" : "robingarcia",\n',
#  '         "description" : "",\n',
#  '         "date" : "2017-03-17 10:34:41",\n',
#  '         "changeDate" : "2017-04-13 09:58:51",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://link.springer.com/book/10.1007/978-3-642-39400-3"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/54388ce4887fa8840f10338ad59ab1da/vascoda",\n',
#  '         "tags" : [\n',
#  '            "fachzugang","biowissenschaft","bibliothek","biologie","zoologie","vascoda","botanik","literaturrecherche"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "54388ce4887fa8840f10338ad59ab1da",\n',
#  '         "label" : "vascoda Fachzugang für Biologie",\n',
#  '         "user" : "vascoda",\n',
#  '         "description" : "(tags: zoologie fachzugang botanik biowissenschaft biologie)",\n',
#  '         "date" : "2009-02-18 15:13:07",\n',
#  '         "changeDate" : "2009-08-28 16:33:16",\n',
#  '         "count" : 2,\n',
#  '         "url" : "http://www.vascoda.de/vascoda?ID=CLD_26_305&LANGUAGE=de"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/54388ce4887fa8840f10338ad59ab1da/mhohlfeld",\n',
#  '         "tags" : [\n',
#  '            "fachzugang","biowissenschaft","bibliothek","biologie","zoologie","vascoda","botanik","literaturrecherche"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "54388ce4887fa8840f10338ad59ab1da",\n',
#  '         "label" : "vascoda Fachzugang für Biologie",\n',
#  '         "user" : "mhohlfeld",\n',
#  '         "description" : "(tags: zoologie fachzugang botanik biowissenschaft biologie)",\n',
#  '         "date" : "2009-02-18 15:13:07",\n',
#  '         "changeDate" : "2009-03-10 15:05:44",\n',
#  '         "count" : 2,\n',
#  '         "url" : "http://www.vascoda.de/vascoda?ID=CLD_26_305&LANGUAGE=de"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/229fcb50b6eba69fce31ed26b64ba52a/domgabfil",\n',
#  '         "tags" : [\n',
#  '            "pdf","langues","yiddish","référence","lexicologie","dictionnaires_bilingues","très_spécialisé"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "229fcb50b6eba69fce31ed26b64ba52a",\n',
#  '         "label" : "Plant Names in Yiddish (YIVO, 2005) [pdf]",\n',
#  '         "user" : "domgabfil",\n',
#  '         "description" : "Groundbreaking Yiddish-English botanical dictionary, draws on literary, scientific, linguistic and religious sources to document a wealth of Yiddish plant names\\u2014including many dialectal and regional variants. It is an essential reference work for Yiddish speakers and readers, scholars, researchers, culinary and nature enthusiasts, historians, scientists, and linguists",\n',
#  '         "date" : "2010-12-17 17:39:57",\n',
#  '         "changeDate" : "2013-01-15 08:22:29",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.yivoinstitute.org/botanik/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/645a4f2b9b39d9e47787882994b776a6/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "645a4f2b9b39d9e47787882994b776a6",\n',
#  '         "label" : "Erbse \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 23:48:20",\n',
#  '         "changeDate" : "2017-05-21 09:35:53",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Erbse"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/05278648bb917ac7b32512f3b0c0e3e9/gvogeler",\n',
#  '         "tags" : [\n',
#  '            "Botanik","Naturwissenschaften","Digitalisierung","Padua","Herbar","Frühe_Neuzeit"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "05278648bb917ac7b32512f3b0c0e3e9",\n',
#  '         "label" : "IPSA - Imaginum Patavinae Scientiae Archivum",\n',
#  '         "user" : "gvogeler",\n',
#  '         "description" : "",\n',
#  '         "date" : "2012-07-30 07:57:32",\n',
#  '         "changeDate" : "2012-07-30 07:57:32",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.ipsa-project.org/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/0cdf9e0d06f2a9511369674cd76eb3ff/vascoda",\n',
#  '         "tags" : [\n',
#  '            "biowissenschaft","bibliothek","fachportal","metasuche","biologie","zoologie","vascoda","botanik","vifa","virtuellefachbibliothek","portal","literaturrecherche"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "0cdf9e0d06f2a9511369674cd76eb3ff",\n',
#  '         "label" : "vifabio -Die virtuelle Fachbibliothek Biologie",\n',
#  '         "user" : "vascoda",\n',
#  '         "description" : "In vifabio werden Katalogdaten, ausgewählte Internetquellen, Zeitschriften, Datenbanken und Volltextdokumente komfortabel auffindbar gemacht.",\n',
#  '         "date" : "2008-12-04 18:46:06",\n',
#  '         "changeDate" : "2009-08-28 16:33:19",\n',
#  '         "count" : 7,\n',
#  '         "url" : "http://www.vifabio.de/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/bd7bb9ed1b85ff38a39ddd0d56908516/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden","minze"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "bd7bb9ed1b85ff38a39ddd0d56908516",\n',
#  '         "label" : "Grüne Minze \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 23:21:53",\n',
#  '         "changeDate" : "2017-05-21 09:37:29",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Gr%C3%BCne_Minze"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/95667531404507793ebd636d8911b39e/continued",\n',
#  '         "tags" : [\n',
#  '            "Botanik","Film","samtig","Obst","Papers","Pfirsich","Haare","Flaum"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "95667531404507793ebd636d8911b39e",\n',
#  '         "label" : "Ever wonder about peach fuzz? [PDF]",\n',
#  '         "user" : "continued",\n',
#  '         "description" : "Waxiness of skin combined with hairs reduce water loss + affect charge of the surface",\n',
#  '         "date" : "2017-06-01 17:35:42",\n',
#  '         "changeDate" : "2017-06-12 17:02:38",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.plantphysiol.org/content/156/4/2098.full.pdf"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/f0058ce1a37507c791bcfdd823501fbc/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "borken","incredible_edible","permaculture","botanik","plants","garden","essbare_stadt"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "f0058ce1a37507c791bcfdd823501fbc",\n',
#  '         "label" : "Essbare Stadt Borken - Internetauftritt des Vereins \\"Essbare Stadt Borken\\"",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 19:05:12",\n',
#  '         "changeDate" : "2017-05-21 09:40:16",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://www.essbare-stadt-borken.de/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/e4eb357daa030a610e3f16d9aa8d0720/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "e4eb357daa030a610e3f16d9aa8d0720",\n',
#  '         "label" : "Tausendkornmasse \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-21 00:17:36",\n',
#  '         "changeDate" : "2017-05-21 09:35:23",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Tausendkornmasse"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/e9142e23d989f7458e82820ba8d87c48/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "transitiontown","permaculture","botanik","plants","garden"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "e9142e23d989f7458e82820ba8d87c48",\n',
#  '         "label" : "Transition Town Projekte 2016 | Transition Town Bielefeld",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 19:07:29",\n',
#  '         "changeDate" : "2017-05-21 09:39:09",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.ttbielefeld.de/node/28"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/6826ae3f314a2728cb951a3ea57655c1/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden","minze","list_of"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "6826ae3f314a2728cb951a3ea57655c1",\n',
#  '         "label" : "Minzen \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 23:27:53",\n',
#  '         "changeDate" : "2017-05-21 09:37:06",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Minzen"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/2d777ffe7cae68cd6fb892f06f6341f2/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","baumrausch","innenstadtgarten","garden"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "2d777ffe7cae68cd6fb892f06f6341f2",\n',
#  '         "label" : "Baumrausch: Eröffnung der Innenstadtgärten 2015",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 21:57:09",\n',
#  '         "changeDate" : "2017-05-21 09:38:07",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.baumrausch.de/aktuelles/news-details/?tx_ttnews%5Btt_news%5D=100&tx_ttnews%5BbackPid%5D=6&cHash=b2e27d09436afcb51a08796af482f1fe"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/f4101d265079e7c03c816b447093c0d0/esistimfluss",\n',
#  '         "tags" : [\n',
#  '            "Botanik","Freizeit","Kiel","Mitgliedschaft","2020"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "f4101d265079e7c03c816b447093c0d0",\n',
#  '         "label" : "Mitgliedschaft Freundeskreis ",\n',
#  '         "user" : "esistimfluss",\n',
#  '         "description" : "",\n',
#  '         "date" : "2020-08-09 13:41:17",\n',
#  '         "changeDate" : "2020-08-09 13:41:17",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.butterbaum.uni-kiel.de/index.php/de/mitgliedschaft"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/0cdf9e0d06f2a9511369674cd76eb3ff/mhohlfeld",\n',
#  '         "tags" : [\n',
#  '            "metasuche","biologie","botanik","virtuellefachbibliothek","fachbibliothek","biowissenschaft","bibliothek","fachportal","zoologie","vascoda","vifa","portal","literaturrecherche"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "0cdf9e0d06f2a9511369674cd76eb3ff",\n',
#  '         "label" : "vifabio -Die virtuelle Fachbibliothek Biologie",\n',
#  '         "user" : "mhohlfeld",\n',
#  '         "description" : "In vifabio werden Katalogdaten, ausgewählte Internetquellen, Zeitschriften, Datenbanken und Volltextdokumente komfortabel auffindbar gemacht.",\n',
#  '         "date" : "2008-12-04 18:46:06",\n',
#  '         "changeDate" : "2009-03-10 15:05:47",\n',
#  '         "count" : 7,\n',
#  '         "url" : "http://www.vifabio.de/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/8b0f9b75d3d332d5d621077df5c4685b/nunatak",\n',
#  '         "tags" : [\n',
#  '            "botanik","bauen"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "8b0f9b75d3d332d5d621077df5c4685b",\n',
#  '         "label" : "baubotanik",\n',
#  '         "user" : "nunatak",\n',
#  '         "description" : "",\n',
#  '         "date" : "2012-04-29 21:11:15",\n',
#  '         "changeDate" : "2012-04-29 21:11:15",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.baubotanik.de/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/15d34f96778a2763d66c41c3a6d3d1e4/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "bielefeld","transitiontown","permaculture","botanik","plants","garden"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "15d34f96778a2763d66c41c3a6d3d1e4",\n',
#  '         "label" : "Transition Town Bielefeld | Transition Town Bielefeld",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 19:05:35",\n',
#  '         "changeDate" : "2017-05-21 09:39:45",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://www.ttbielefeld.de/"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/8d5867cc0485b9417726588ca705f385/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden","minze"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "8d5867cc0485b9417726588ca705f385",\n',
#  '         "label" : "Nanaminze \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 23:21:56",\n',
#  '         "changeDate" : "2017-05-21 09:37:18",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Nanaminze"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/2810cc2d190da1b75662f74ff1714521/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden","minze"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "2810cc2d190da1b75662f74ff1714521",\n',
#  '         "label" : "Rundblättrige Minze \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 23:30:13",\n',
#  '         "changeDate" : "2017-05-21 09:36:47",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Rundbl%C3%A4ttrige_Minze"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/c465359be791b0c18cc4cb3dbcfd7ea9/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "akademie","permaculture","botanik","plants","literatur","toexplore","garden"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "c465359be791b0c18cc4cb3dbcfd7ea9",\n',
#  '         "label" : "Permakultur Akademie: Infothek: Literatur: Literatur zur Permakultur",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 19:22:52",\n',
#  '         "changeDate" : "2017-05-21 09:38:33",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://permakultur-akademie.de/front_content.php?idcat=44&lang=1"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/e76964733861eec4eb4033f8ebeac9d4/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "permaculture","botanik","plants","garden","minze"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "e76964733861eec4eb4033f8ebeac9d4",\n',
#  '         "label" : "Acker-Minze \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-20 23:16:17",\n',
#  '         "changeDate" : "2017-05-21 09:37:40",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Acker-Minze"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/21895e0da2bcb8f39e259edc76ac3dfd/schmidt2",\n',
#  '         "tags" : [\n',
#  '            "bioindicator","gardening","biologie","botanik","zeigerpflanze"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "21895e0da2bcb8f39e259edc76ac3dfd",\n',
#  '         "label" : "Zeigerpflanze \\u2013 Wikipedia",\n',
#  '         "user" : "schmidt2",\n',
#  '         "description" : "a bookmark",\n',
#  '         "date" : "2017-05-29 06:27:10",\n',
#  '         "changeDate" : "2017-06-09 16:50:08",\n',
#  '         "count" : 1,\n',
#  '         "url" : "https://de.m.wikipedia.org/wiki/Zeigerpflanze"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '\t  {  \n',
#  '         "type" : "Bookmark",\n',
#  '         "id"   : "https://www.bibsonomy.org/url/e3c382be174816d25fbffe6185682cd9/lysander07",\n',
#  '         "tags" : [\n',
#  '            "rezension","biblionomicon","2012","frauen","biography"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "e3c382be174816d25fbffe6185682cd9",\n',
#  '         "label" : "BIBLIONOMICON: Verwegene Frauen - Liv Winterberg \'Vom anderen Ende der Welt\'",\n',
#  '         "user" : "lysander07",\n',
#  '         "description" : "Rezension zu Liv Winterbergs Roman über das Leben der Jeanne Baré, die als Mann verkleidet an Entdeckungsfahrten in die Südsee teilnahm und als Wissenschaftlerin wertvolle Beiträge zur Botanik leistete....via Biblionomicon",\n',
#  '         "date" : "2012-01-23 13:54:43",\n',
#  '         "changeDate" : "2012-01-23 13:54:43",\n',
#  '         "count" : 1,\n',
#  '         "url" : "http://biblionomicon.blogspot.com/2012/01/verwegene-frauen-liv-winterberg-vom.html"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/229b8e5804a2b7e8dc98760dcf9511b54/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "29b8e5804a2b7e8dc98760dcf9511b54",\n',
#  '         "interHash" : "654e839263f94e4738888a527d5364b0",\n',
#  '         "label" : "Dynamik der Thylakoidmembran ergrünender Chlorella fusca g 2: Entwicklung von Ultrastruktur und Funktion des Photosyntheseapparates",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 06:54:57",\n',
#  '         "changeDate" : "2015-09-09 06:54:57",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1986", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Elisabeth Przibilla"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Elisabeth",\t"last" : "Przibilla"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "870814451",\n',
#  '         \n',
#  '         "bibtexKey": "przibilla1986dynamik"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/25364c8d0f8696590b2c77f1f54369c29/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Botanik","Umweltschutz","Landschaftsgestaltung","Elektronik","Industrielle_und_handwerkliche_Fertigung","merged:genealogie","Fertigungstechnik","Ingenieurwissenschaften_und_Maschinenbau","Umwelttechnik","Energie-","Bautechnik","Raumordnung","Bergbau","dnb","Elektrotechnik","Energiewirtschaft","Maschinen"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "5364c8d0f8696590b2c77f1f54369c29",\n',
#  '         "interHash" : "2fce69f6d7e22e250e4105a8c9ced5f8",\n',
#  '         "label" : "Weiterentwicklung der Methoden und Daten zur Berechnung des Radionuklidtransportes von der Luft in die Pflanzen um kerntechnische Anlagen",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 05:28:16",\n',
#  '         "changeDate" : "2015-09-09 05:28:16",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1984", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Margot Horn"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Margot",\t"last" : "Horn"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "850076021",\n',
#  '         \n',
#  '         "bibtexKey": "horn1984weiterentwicklung"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2806c8900b42892c085142102ee2e881e/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "806c8900b42892c085142102ee2e881e",\n',
#  '         "interHash" : "d131194a872de421ccdecb348ca7e8de",\n',
#  '         "label" : "Induktion von Chloramphenicol-Resistenz und interspezifischem Organelltransfer bei Nicotiana plumbaginifolia in Zellkulturen",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 05:44:03",\n',
#  '         "changeDate" : "2015-09-09 05:44:03",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1984", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Roswitha Golling"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Roswitha",\t"last" : "Golling"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "850535824",\n',
#  '         \n',
#  '         "bibtexKey": "golling1984induktion"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2f3bbc635b3e7a40ee8ce7ec8e89c9176/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Garten","Botanik","Landwirtschaft","Land_und_Forstwirtschaft","dnb","merged:genealogie","Veterinärmedizin","Biologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "f3bbc635b3e7a40ee8ce7ec8e89c9176",\n',
#  '         "interHash" : "986cd940ea5eff184a5f1d5941d94f66",\n',
#  '         "label" : "Die Pathogenese des Pezicula-Krebses der amerikanischen Roteiche (Quercus rubra L.), verursacht durch Pezicula cinnamomea (DC.) Sacc., im Vergleich mit anderen Rindenerkrankungen der Eiche",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 08:19:41",\n',
#  '         "changeDate" : "2015-09-09 08:19:41",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1989", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Rolf Dieter Kehr"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Rolf Dieter",\t"last" : "Kehr"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "891271481",\n',
#  '         \n',
#  '         "bibtexKey": "kehr1989pathogenese"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/25e4bd2c95f4ca7c97d22ea203fbbb85e/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "5e4bd2c95f4ca7c97d22ea203fbbb85e",\n',
#  '         "interHash" : "3607bdb262ef58572eefaf129508a984",\n',
#  '         "label" : "Die chilenischen Arten der Gattung Sisyrinchium L. (Iridaceae)",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 07:07:15",\n',
#  '         "changeDate" : "2015-09-09 07:07:15",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1986", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Roberto Rodríguez Rios"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Roberto",\t"last" : "Rodríguez Rios"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "871322692",\n',
#  '         \n',
#  '         "bibtexKey": "rodriguezrios1986chilenischen"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2197c71747753a68ef3d7e06188ab19ef/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "197c71747753a68ef3d7e06188ab19ef",\n',
#  '         "interHash" : "8904da62bda88062abb9d7ec20508683",\n',
#  '         "label" : "Physiologische und biochemische Untersuchungen an dem Cyanellen enthaltenden Flagellat Cyanophora paradoxa und an Rhopalodia gibba, einer Diatomee mit blau-grünen Einschlüssen",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 04:20:52",\n',
#  '         "changeDate" : "2015-09-09 04:20:52",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1982", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Liliane Floener"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Liliane",\t"last" : "Floener"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "830021108",\n',
#  '         \n',
#  '         "bibtexKey": "floener1982physiologische"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2d96b6c1317b47237ac51b061fd2ce178/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "d96b6c1317b47237ac51b061fd2ce178",\n',
#  '         "interHash" : "14bd4269e150a36b6cf548b6e701d56e",\n',
#  '         "label" : "Stoffwechselphysiologische Untersuchungen zum Problem der obligaten Phototrophie bei der volvocalen Grünalge Chlamydobotrys stellata",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 04:02:30",\n',
#  '         "changeDate" : "2015-09-09 04:02:30",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1981", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Edgar Luck"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Edgar",\t"last" : "Luck"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "820595128",\n',
#  '         \n',
#  '         "bibtexKey": "luck1981stoffwechselphysiologische"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2be1c69598eadd4b2976ae22c03677715/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "be1c69598eadd4b2976ae22c03677715",\n',
#  '         "interHash" : "05fdc7807eb02226b8f0c5ea9de832b0",\n',
#  '         "label" : "Untersuchungen zur Charakterisierung und Regulation der 3-Hydroxy-3-methylglutaryl-Coenzym-A-Reduktase Hydroxy-methylglutaryl-Coenzym-A-Reduktase (Mevalonat: NADP_1hn+ NADP Oxidoreduktase, CoA acylierend, E.C. 1.1.1.34 eins eins eins vierunddreissig) in Keimlingen von Raphanus sativus",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 03:50:41",\n',
#  '         "changeDate" : "2015-09-09 03:50:41",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1981", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Thomas Bach"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Thomas",\t"last" : "Bach"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "820146870",\n',
#  '         \n',
#  '         "bibtexKey": "bach1981untersuchungen"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2b76c67bdb6755d33695a0ef952a44bc3/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "b76c67bdb6755d33695a0ef952a44bc3",\n',
#  '         "interHash" : "5f7bc6473b65cf1ca2397aa023a78fd1",\n',
#  '         "label" : "Sensorische und gaschromatographische Untersuchungen zum off-Flavour von Ackerbohnensamen und -proteinisolat: e. Beitr. zur Subjektiven Gustometrie u. Olfaktometrie#1hn,#1hn, u. zur Reaktionskinetik sensor. Veränderungen",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-08 10:08:38",\n',
#  '         "changeDate" : "2015-09-08 10:08:38",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1976", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Ulf Seidel"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Ulf",\t"last" : "Seidel"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "213364700",\n',
#  '         \n',
#  '         "bibtexKey": "seidel1976sensorische"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2e6aee650c2970015e01dcbfaa606847f/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "e6aee650c2970015e01dcbfaa606847f",\n',
#  '         "interHash" : "fc569922004c7326dbecb904bf548a28",\n',
#  '         "label" : "Toleranzmechanismen von Flechten gegenüber natürlicher und anthropogener Belastung: In-vivo-Chloroplastenfluoreszenz als charakteristisches Kriterium und Grundlage für ein Stress-Reaktionsmodell",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 07:21:41",\n',
#  '         "changeDate" : "2015-09-09 07:21:41",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1987", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Hans-Joachim Lühmann"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Hans-Joachim",\t"last" : "Lühmann"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "880401400",\n',
#  '         \n',
#  '         "bibtexKey": "luhmann1987toleranzmechanismen"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2a42e94098d6d65d9bd99a0c3522ab236/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "a42e94098d6d65d9bd99a0c3522ab236",\n',
#  '         "interHash" : "78ceb90ca3aed274a5302efbf3b3bb2a",\n',
#  '         "label" : "Das vakuoläre System aus Zellsuspensionskulturen der Tomate (Lycopersicon esculentum): Isolierung u. Charakterisierung",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 06:06:48",\n',
#  '         "changeDate" : "2015-09-09 06:06:48",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1985", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Konrad Glund"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Konrad",\t"last" : "Glund"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "860202984",\n',
#  '         \n',
#  '         "bibtexKey": "glund1985vakuolre"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2259dca36755d5b0cd80fac4e3a485254/genealogie",         \n',
#  '         "tags" : [\n',
#  '            "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "259dca36755d5b0cd80fac4e3a485254",\n',
#  '         "interHash" : "6b62eac8b998351f4eefda31c03feb97",\n',
#  '         "label" : "CAM-Ausprägung in Plectranthus marrubioides Benth. (Fam. Laminaceae): Einfluss der Faktoren Licht, Blattemperatur, Luftfeuchtigkeit, Bodenwasserverfügbarkeit und Blattwasserzustand",\n',
#  '         "user" : "genealogie",\n',
#  '         "description" : "",\n',
#  '         "date" : "2015-09-09 08:28:44",\n',
#  '         "changeDate" : "2015-09-09 08:28:44",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "phdthesis",\n',
#  '         \n',
#  '         "year": "1989", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "Werner Herppich"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "Werner",\t"last" : "Herppich"}\n',
#  '         ],\n',
#  '         \n',
#  '         "dnbtitleid" : "891547835",\n',
#  '         \n',
#  '         "bibtexKey": "herppich1989camausprgung"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2e49d4de272be8c4d6003f87f7393566c/rwst",         \n',
#  '         "tags" : [\n',
#  '            "Botanik","Genetik","Vor1950","Asteraceae","merged:rwst"\n',
#  '         ],\n',
#  '         \n',
#  '         "intraHash" : "e49d4de272be8c4d6003f87f7393566c",\n',
#  '         "interHash" : "7c932914a59db9d31e641fdf6bed9674",\n',
#  '         "label" : "Zur Kenntnis der Apogamie in der Gattung Hieracium",\n',
#  '         "user" : "rwst",\n',
#  '         "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",\n',
#  '         "date" : "2009-08-02 16:40:10",\n',
#  '         "changeDate" : "2009-08-02 16:40:11",\n',
#  '         "count" : 1,\n',
#  '         "pub-type": "article",\n',
#  '         "journal": "Berichte der Deutsch. Botan. Gesellsch.",\n',
#  '         "year": "1904", \n',
#  '         "url": "", \n',
#  '         \n',
#  '         "author": [ \n',
#  '            "C. Ostenfeld"\n',
#  '         ],\n',
#  '         "authors": [\n',
#  '         \t\n',
#  '            \t{"first" : "C.",\t"last" : "Ostenfeld"}\n',
#  '         ],\n',
#  '         "volume": "XXII","pages": "376",\n',
#  '         "bibtexKey": "O"\n',
#  '\n',
#  '      }\n',
#  ',\n',
#  '      {\n',
#  '         "type" : "Publication",\n',
#  '         "id"   : "https://www.bibsonomy.org/bibtex/2e612e5827e1797ee70bfd9a7af45bc2c/genealogie",         \n',
#  '         "tags" : [\n',
#  ...]

# %%
# Überflüssige Leerzeichen entfernen
with open ('botanik.json','r') as botanik_infile:
    for line in botanik_infile:
        print(line.strip())
# Out:
# {
# "types" : {
# "Bookmark" : {
# "pluralLabel" : "Bookmarks"
# },
# "Publication" : {
# "pluralLabel" : "Publications"
# },
# "GoldStandardPublication" : {
# "pluralLabel" : "GoldStandardPublications"
# },
# "GoldStandardBookmark" : {
# "pluralLabel" : "GoldStandardBookmarks"
# },
# "Tag" : {
# "pluralLabel" : "Tags"
# },
# "User" : {
# "pluralLabel" : "Users"
# },
# "Sphere" : {
# "pluralLabel" : "Spheres"
# }
# },
#
# "properties" : {
# "count" : {
# "valueType" : "number"
# },
# "date" : {
# "valueType" : "date"
# },
# "changeDate" : {
# "valueType" : "date"
# },
# "url" : {
# "valueType" : "url"
# },
# "id" : {
# "valueType" : "url"
# },
# "tags" : {
# "valueType" : "item"
# },
# "user" : {
# "valueType" : "item"
# }
# },
#
# "items" : [
#
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/151a9bb7aadbb8f9cd7516d287ef842a/schmidt2",
# "tags" : [
# "from_android"
# ],
#
# "intraHash" : "151a9bb7aadbb8f9cd7516d287ef842a",
# "label" : "Weiden (Botanik) \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-06-02 23:46:33",
# "changeDate" : "2017-06-02 23:46:33",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Weiden_(Botanik)"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/279da9197ac94560b25d4fad31e097b0/schmidt2",
# "tags" : [
# "from_android"
# ],
#
# "intraHash" : "279da9197ac94560b25d4fad31e097b0",
# "label" : "Horst (Botanik) \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2018-05-01 18:28:10",
# "changeDate" : "2018-05-01 18:28:10",
# "count" : 1,
# "url" : "https://de.wikipedia.org/wiki/Horst_(Botanik)"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/6c693298cf621782f51ed684a92a576e/karinnadrowski",
# "tags" : [
# "spezbot","botanik","spezielle"
# ],
#
# "intraHash" : "6c693298cf621782f51ed684a92a576e",
# "label" : "Spezielle Botanik und funktionelle Biodiversität",
# "user" : "karinnadrowski",
# "description" : "",
# "date" : "2011-02-13 13:47:31",
# "changeDate" : "2011-02-13 13:47:31",
# "count" : 1,
# "url" : "http://alfresco.uni-leipzig.de/spezbot/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/eb7eebfa272a71cc44009253bcecfed2/schmidt2",
# "tags" : [
# "from_android"
# ],
#
# "intraHash" : "eb7eebfa272a71cc44009253bcecfed2",
# "label" : "Botanik - Wüstenpflanze erntet Wasser aus der Luft - Wissen - Süddeutsche.de",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2018-05-07 09:40:28",
# "changeDate" : "2018-05-07 09:40:28",
# "count" : 1,
# "url" : "http://www.sueddeutsche.de/wissen/botanik-wuestenpflanze-erntet-wasser-aus-der-luft-1.3021848"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/fa8e601741b670106589bbd019a32b5a/robingarcia",
# "tags" : [
# "Unsortierte_Lesezeichen"
# ],
#
# "intraHash" : "fa8e601741b670106589bbd019a32b5a",
# "label" : "Geschichte der Botanik - Springer",
# "user" : "robingarcia",
# "description" : "",
# "date" : "2017-03-17 10:34:41",
# "changeDate" : "2017-04-13 09:58:51",
# "count" : 1,
# "url" : "http://link.springer.com/book/10.1007/978-3-642-39400-3"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/54388ce4887fa8840f10338ad59ab1da/vascoda",
# "tags" : [
# "fachzugang","biowissenschaft","bibliothek","biologie","zoologie","vascoda","botanik","literaturrecherche"
# ],
#
# "intraHash" : "54388ce4887fa8840f10338ad59ab1da",
# "label" : "vascoda Fachzugang für Biologie",
# "user" : "vascoda",
# "description" : "(tags: zoologie fachzugang botanik biowissenschaft biologie)",
# "date" : "2009-02-18 15:13:07",
# "changeDate" : "2009-08-28 16:33:16",
# "count" : 2,
# "url" : "http://www.vascoda.de/vascoda?ID=CLD_26_305&LANGUAGE=de"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/54388ce4887fa8840f10338ad59ab1da/mhohlfeld",
# "tags" : [
# "fachzugang","biowissenschaft","bibliothek","biologie","zoologie","vascoda","botanik","literaturrecherche"
# ],
#
# "intraHash" : "54388ce4887fa8840f10338ad59ab1da",
# "label" : "vascoda Fachzugang für Biologie",
# "user" : "mhohlfeld",
# "description" : "(tags: zoologie fachzugang botanik biowissenschaft biologie)",
# "date" : "2009-02-18 15:13:07",
# "changeDate" : "2009-03-10 15:05:44",
# "count" : 2,
# "url" : "http://www.vascoda.de/vascoda?ID=CLD_26_305&LANGUAGE=de"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/229fcb50b6eba69fce31ed26b64ba52a/domgabfil",
# "tags" : [
# "pdf","langues","yiddish","référence","lexicologie","dictionnaires_bilingues","très_spécialisé"
# ],
#
# "intraHash" : "229fcb50b6eba69fce31ed26b64ba52a",
# "label" : "Plant Names in Yiddish (YIVO, 2005) [pdf]",
# "user" : "domgabfil",
# "description" : "Groundbreaking Yiddish-English botanical dictionary, draws on literary, scientific, linguistic and religious sources to document a wealth of Yiddish plant names\u2014including many dialectal and regional variants. It is an essential reference work for Yiddish speakers and readers, scholars, researchers, culinary and nature enthusiasts, historians, scientists, and linguists",
# "date" : "2010-12-17 17:39:57",
# "changeDate" : "2013-01-15 08:22:29",
# "count" : 1,
# "url" : "http://www.yivoinstitute.org/botanik/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/645a4f2b9b39d9e47787882994b776a6/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "645a4f2b9b39d9e47787882994b776a6",
# "label" : "Erbse \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:48:20",
# "changeDate" : "2017-05-21 09:35:53",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Erbse"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/05278648bb917ac7b32512f3b0c0e3e9/gvogeler",
# "tags" : [
# "Botanik","Naturwissenschaften","Digitalisierung","Padua","Herbar","Frühe_Neuzeit"
# ],
#
# "intraHash" : "05278648bb917ac7b32512f3b0c0e3e9",
# "label" : "IPSA - Imaginum Patavinae Scientiae Archivum",
# "user" : "gvogeler",
# "description" : "",
# "date" : "2012-07-30 07:57:32",
# "changeDate" : "2012-07-30 07:57:32",
# "count" : 1,
# "url" : "http://www.ipsa-project.org/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/0cdf9e0d06f2a9511369674cd76eb3ff/vascoda",
# "tags" : [
# "biowissenschaft","bibliothek","fachportal","metasuche","biologie","zoologie","vascoda","botanik","vifa","virtuellefachbibliothek","portal","literaturrecherche"
# ],
#
# "intraHash" : "0cdf9e0d06f2a9511369674cd76eb3ff",
# "label" : "vifabio -Die virtuelle Fachbibliothek Biologie",
# "user" : "vascoda",
# "description" : "In vifabio werden Katalogdaten, ausgewählte Internetquellen, Zeitschriften, Datenbanken und Volltextdokumente komfortabel auffindbar gemacht.",
# "date" : "2008-12-04 18:46:06",
# "changeDate" : "2009-08-28 16:33:19",
# "count" : 7,
# "url" : "http://www.vifabio.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/bd7bb9ed1b85ff38a39ddd0d56908516/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "bd7bb9ed1b85ff38a39ddd0d56908516",
# "label" : "Grüne Minze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:21:53",
# "changeDate" : "2017-05-21 09:37:29",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Gr%C3%BCne_Minze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/95667531404507793ebd636d8911b39e/continued",
# "tags" : [
# "Botanik","Film","samtig","Obst","Papers","Pfirsich","Haare","Flaum"
# ],
#
# "intraHash" : "95667531404507793ebd636d8911b39e",
# "label" : "Ever wonder about peach fuzz? [PDF]",
# "user" : "continued",
# "description" : "Waxiness of skin combined with hairs reduce water loss + affect charge of the surface",
# "date" : "2017-06-01 17:35:42",
# "changeDate" : "2017-06-12 17:02:38",
# "count" : 1,
# "url" : "http://www.plantphysiol.org/content/156/4/2098.full.pdf"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/f0058ce1a37507c791bcfdd823501fbc/schmidt2",
# "tags" : [
# "borken","incredible_edible","permaculture","botanik","plants","garden","essbare_stadt"
# ],
#
# "intraHash" : "f0058ce1a37507c791bcfdd823501fbc",
# "label" : "Essbare Stadt Borken - Internetauftritt des Vereins \"Essbare Stadt Borken\"",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:05:12",
# "changeDate" : "2017-05-21 09:40:16",
# "count" : 1,
# "url" : "https://www.essbare-stadt-borken.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e4eb357daa030a610e3f16d9aa8d0720/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "e4eb357daa030a610e3f16d9aa8d0720",
# "label" : "Tausendkornmasse \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-21 00:17:36",
# "changeDate" : "2017-05-21 09:35:23",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Tausendkornmasse"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e9142e23d989f7458e82820ba8d87c48/schmidt2",
# "tags" : [
# "transitiontown","permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "e9142e23d989f7458e82820ba8d87c48",
# "label" : "Transition Town Projekte 2016 | Transition Town Bielefeld",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:07:29",
# "changeDate" : "2017-05-21 09:39:09",
# "count" : 1,
# "url" : "http://www.ttbielefeld.de/node/28"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/6826ae3f314a2728cb951a3ea57655c1/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze","list_of"
# ],
#
# "intraHash" : "6826ae3f314a2728cb951a3ea57655c1",
# "label" : "Minzen \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:27:53",
# "changeDate" : "2017-05-21 09:37:06",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Minzen"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/2d777ffe7cae68cd6fb892f06f6341f2/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","baumrausch","innenstadtgarten","garden"
# ],
#
# "intraHash" : "2d777ffe7cae68cd6fb892f06f6341f2",
# "label" : "Baumrausch: Eröffnung der Innenstadtgärten 2015",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 21:57:09",
# "changeDate" : "2017-05-21 09:38:07",
# "count" : 1,
# "url" : "http://www.baumrausch.de/aktuelles/news-details/?tx_ttnews%5Btt_news%5D=100&tx_ttnews%5BbackPid%5D=6&cHash=b2e27d09436afcb51a08796af482f1fe"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/f4101d265079e7c03c816b447093c0d0/esistimfluss",
# "tags" : [
# "Botanik","Freizeit","Kiel","Mitgliedschaft","2020"
# ],
#
# "intraHash" : "f4101d265079e7c03c816b447093c0d0",
# "label" : "Mitgliedschaft Freundeskreis ",
# "user" : "esistimfluss",
# "description" : "",
# "date" : "2020-08-09 13:41:17",
# "changeDate" : "2020-08-09 13:41:17",
# "count" : 1,
# "url" : "http://www.butterbaum.uni-kiel.de/index.php/de/mitgliedschaft"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/0cdf9e0d06f2a9511369674cd76eb3ff/mhohlfeld",
# "tags" : [
# "metasuche","biologie","botanik","virtuellefachbibliothek","fachbibliothek","biowissenschaft","bibliothek","fachportal","zoologie","vascoda","vifa","portal","literaturrecherche"
# ],
#
# "intraHash" : "0cdf9e0d06f2a9511369674cd76eb3ff",
# "label" : "vifabio -Die virtuelle Fachbibliothek Biologie",
# "user" : "mhohlfeld",
# "description" : "In vifabio werden Katalogdaten, ausgewählte Internetquellen, Zeitschriften, Datenbanken und Volltextdokumente komfortabel auffindbar gemacht.",
# "date" : "2008-12-04 18:46:06",
# "changeDate" : "2009-03-10 15:05:47",
# "count" : 7,
# "url" : "http://www.vifabio.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/8b0f9b75d3d332d5d621077df5c4685b/nunatak",
# "tags" : [
# "botanik","bauen"
# ],
#
# "intraHash" : "8b0f9b75d3d332d5d621077df5c4685b",
# "label" : "baubotanik",
# "user" : "nunatak",
# "description" : "",
# "date" : "2012-04-29 21:11:15",
# "changeDate" : "2012-04-29 21:11:15",
# "count" : 1,
# "url" : "http://www.baubotanik.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/15d34f96778a2763d66c41c3a6d3d1e4/schmidt2",
# "tags" : [
# "bielefeld","transitiontown","permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "15d34f96778a2763d66c41c3a6d3d1e4",
# "label" : "Transition Town Bielefeld | Transition Town Bielefeld",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:05:35",
# "changeDate" : "2017-05-21 09:39:45",
# "count" : 1,
# "url" : "http://www.ttbielefeld.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/8d5867cc0485b9417726588ca705f385/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "8d5867cc0485b9417726588ca705f385",
# "label" : "Nanaminze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:21:56",
# "changeDate" : "2017-05-21 09:37:18",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Nanaminze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/2810cc2d190da1b75662f74ff1714521/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "2810cc2d190da1b75662f74ff1714521",
# "label" : "Rundblättrige Minze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:30:13",
# "changeDate" : "2017-05-21 09:36:47",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Rundbl%C3%A4ttrige_Minze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/c465359be791b0c18cc4cb3dbcfd7ea9/schmidt2",
# "tags" : [
# "akademie","permaculture","botanik","plants","literatur","toexplore","garden"
# ],
#
# "intraHash" : "c465359be791b0c18cc4cb3dbcfd7ea9",
# "label" : "Permakultur Akademie: Infothek: Literatur: Literatur zur Permakultur",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:22:52",
# "changeDate" : "2017-05-21 09:38:33",
# "count" : 1,
# "url" : "https://permakultur-akademie.de/front_content.php?idcat=44&lang=1"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e76964733861eec4eb4033f8ebeac9d4/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "e76964733861eec4eb4033f8ebeac9d4",
# "label" : "Acker-Minze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:16:17",
# "changeDate" : "2017-05-21 09:37:40",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Acker-Minze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/21895e0da2bcb8f39e259edc76ac3dfd/schmidt2",
# "tags" : [
# "bioindicator","gardening","biologie","botanik","zeigerpflanze"
# ],
#
# "intraHash" : "21895e0da2bcb8f39e259edc76ac3dfd",
# "label" : "Zeigerpflanze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-29 06:27:10",
# "changeDate" : "2017-06-09 16:50:08",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Zeigerpflanze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e3c382be174816d25fbffe6185682cd9/lysander07",
# "tags" : [
# "rezension","biblionomicon","2012","frauen","biography"
# ],
#
# "intraHash" : "e3c382be174816d25fbffe6185682cd9",
# "label" : "BIBLIONOMICON: Verwegene Frauen - Liv Winterberg 'Vom anderen Ende der Welt'",
# "user" : "lysander07",
# "description" : "Rezension zu Liv Winterbergs Roman über das Leben der Jeanne Baré, die als Mann verkleidet an Entdeckungsfahrten in die Südsee teilnahm und als Wissenschaftlerin wertvolle Beiträge zur Botanik leistete....via Biblionomicon",
# "date" : "2012-01-23 13:54:43",
# "changeDate" : "2012-01-23 13:54:43",
# "count" : 1,
# "url" : "http://biblionomicon.blogspot.com/2012/01/verwegene-frauen-liv-winterberg-vom.html"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/229b8e5804a2b7e8dc98760dcf9511b54/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "29b8e5804a2b7e8dc98760dcf9511b54",
# "interHash" : "654e839263f94e4738888a527d5364b0",
# "label" : "Dynamik der Thylakoidmembran ergrünender Chlorella fusca g 2: Entwicklung von Ultrastruktur und Funktion des Photosyntheseapparates",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:54:57",
# "changeDate" : "2015-09-09 06:54:57",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Elisabeth Przibilla"
# ],
# "authors": [
#
# {"first" : "Elisabeth",	"last" : "Przibilla"}
# ],
#
# "dnbtitleid" : "870814451",
#
# "bibtexKey": "przibilla1986dynamik"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25364c8d0f8696590b2c77f1f54369c29/genealogie",
# "tags" : [
# "Botanik","Umweltschutz","Landschaftsgestaltung","Elektronik","Industrielle_und_handwerkliche_Fertigung","merged:genealogie","Fertigungstechnik","Ingenieurwissenschaften_und_Maschinenbau","Umwelttechnik","Energie-","Bautechnik","Raumordnung","Bergbau","dnb","Elektrotechnik","Energiewirtschaft","Maschinen"
# ],
#
# "intraHash" : "5364c8d0f8696590b2c77f1f54369c29",
# "interHash" : "2fce69f6d7e22e250e4105a8c9ced5f8",
# "label" : "Weiterentwicklung der Methoden und Daten zur Berechnung des Radionuklidtransportes von der Luft in die Pflanzen um kerntechnische Anlagen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:28:16",
# "changeDate" : "2015-09-09 05:28:16",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Margot Horn"
# ],
# "authors": [
#
# {"first" : "Margot",	"last" : "Horn"}
# ],
#
# "dnbtitleid" : "850076021",
#
# "bibtexKey": "horn1984weiterentwicklung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2806c8900b42892c085142102ee2e881e/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "806c8900b42892c085142102ee2e881e",
# "interHash" : "d131194a872de421ccdecb348ca7e8de",
# "label" : "Induktion von Chloramphenicol-Resistenz und interspezifischem Organelltransfer bei Nicotiana plumbaginifolia in Zellkulturen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:44:03",
# "changeDate" : "2015-09-09 05:44:03",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Roswitha Golling"
# ],
# "authors": [
#
# {"first" : "Roswitha",	"last" : "Golling"}
# ],
#
# "dnbtitleid" : "850535824",
#
# "bibtexKey": "golling1984induktion"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2f3bbc635b3e7a40ee8ce7ec8e89c9176/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","Land_und_Forstwirtschaft","dnb","merged:genealogie","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "f3bbc635b3e7a40ee8ce7ec8e89c9176",
# "interHash" : "986cd940ea5eff184a5f1d5941d94f66",
# "label" : "Die Pathogenese des Pezicula-Krebses der amerikanischen Roteiche (Quercus rubra L.), verursacht durch Pezicula cinnamomea (DC.) Sacc., im Vergleich mit anderen Rindenerkrankungen der Eiche",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:19:41",
# "changeDate" : "2015-09-09 08:19:41",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1989",
# "url": "",
#
# "author": [
# "Rolf Dieter Kehr"
# ],
# "authors": [
#
# {"first" : "Rolf Dieter",	"last" : "Kehr"}
# ],
#
# "dnbtitleid" : "891271481",
#
# "bibtexKey": "kehr1989pathogenese"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25e4bd2c95f4ca7c97d22ea203fbbb85e/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "5e4bd2c95f4ca7c97d22ea203fbbb85e",
# "interHash" : "3607bdb262ef58572eefaf129508a984",
# "label" : "Die chilenischen Arten der Gattung Sisyrinchium L. (Iridaceae)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:07:15",
# "changeDate" : "2015-09-09 07:07:15",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Roberto Rodríguez Rios"
# ],
# "authors": [
#
# {"first" : "Roberto",	"last" : "Rodríguez Rios"}
# ],
#
# "dnbtitleid" : "871322692",
#
# "bibtexKey": "rodriguezrios1986chilenischen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2197c71747753a68ef3d7e06188ab19ef/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "197c71747753a68ef3d7e06188ab19ef",
# "interHash" : "8904da62bda88062abb9d7ec20508683",
# "label" : "Physiologische und biochemische Untersuchungen an dem Cyanellen enthaltenden Flagellat Cyanophora paradoxa und an Rhopalodia gibba, einer Diatomee mit blau-grünen Einschlüssen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:20:52",
# "changeDate" : "2015-09-09 04:20:52",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Liliane Floener"
# ],
# "authors": [
#
# {"first" : "Liliane",	"last" : "Floener"}
# ],
#
# "dnbtitleid" : "830021108",
#
# "bibtexKey": "floener1982physiologische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d96b6c1317b47237ac51b061fd2ce178/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "d96b6c1317b47237ac51b061fd2ce178",
# "interHash" : "14bd4269e150a36b6cf548b6e701d56e",
# "label" : "Stoffwechselphysiologische Untersuchungen zum Problem der obligaten Phototrophie bei der volvocalen Grünalge Chlamydobotrys stellata",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:02:30",
# "changeDate" : "2015-09-09 04:02:30",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Edgar Luck"
# ],
# "authors": [
#
# {"first" : "Edgar",	"last" : "Luck"}
# ],
#
# "dnbtitleid" : "820595128",
#
# "bibtexKey": "luck1981stoffwechselphysiologische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2be1c69598eadd4b2976ae22c03677715/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "be1c69598eadd4b2976ae22c03677715",
# "interHash" : "05fdc7807eb02226b8f0c5ea9de832b0",
# "label" : "Untersuchungen zur Charakterisierung und Regulation der 3-Hydroxy-3-methylglutaryl-Coenzym-A-Reduktase Hydroxy-methylglutaryl-Coenzym-A-Reduktase (Mevalonat: NADP_1hn+ NADP Oxidoreduktase, CoA acylierend, E.C. 1.1.1.34 eins eins eins vierunddreissig) in Keimlingen von Raphanus sativus",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:50:41",
# "changeDate" : "2015-09-09 03:50:41",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Thomas Bach"
# ],
# "authors": [
#
# {"first" : "Thomas",	"last" : "Bach"}
# ],
#
# "dnbtitleid" : "820146870",
#
# "bibtexKey": "bach1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2b76c67bdb6755d33695a0ef952a44bc3/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "b76c67bdb6755d33695a0ef952a44bc3",
# "interHash" : "5f7bc6473b65cf1ca2397aa023a78fd1",
# "label" : "Sensorische und gaschromatographische Untersuchungen zum off-Flavour von Ackerbohnensamen und -proteinisolat: e. Beitr. zur Subjektiven Gustometrie u. Olfaktometrie#1hn,#1hn, u. zur Reaktionskinetik sensor. Veränderungen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 10:08:38",
# "changeDate" : "2015-09-08 10:08:38",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1976",
# "url": "",
#
# "author": [
# "Ulf Seidel"
# ],
# "authors": [
#
# {"first" : "Ulf",	"last" : "Seidel"}
# ],
#
# "dnbtitleid" : "213364700",
#
# "bibtexKey": "seidel1976sensorische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e6aee650c2970015e01dcbfaa606847f/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "e6aee650c2970015e01dcbfaa606847f",
# "interHash" : "fc569922004c7326dbecb904bf548a28",
# "label" : "Toleranzmechanismen von Flechten gegenüber natürlicher und anthropogener Belastung: In-vivo-Chloroplastenfluoreszenz als charakteristisches Kriterium und Grundlage für ein Stress-Reaktionsmodell",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:21:41",
# "changeDate" : "2015-09-09 07:21:41",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Hans-Joachim Lühmann"
# ],
# "authors": [
#
# {"first" : "Hans-Joachim",	"last" : "Lühmann"}
# ],
#
# "dnbtitleid" : "880401400",
#
# "bibtexKey": "luhmann1987toleranzmechanismen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2a42e94098d6d65d9bd99a0c3522ab236/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "a42e94098d6d65d9bd99a0c3522ab236",
# "interHash" : "78ceb90ca3aed274a5302efbf3b3bb2a",
# "label" : "Das vakuoläre System aus Zellsuspensionskulturen der Tomate (Lycopersicon esculentum): Isolierung u. Charakterisierung",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:06:48",
# "changeDate" : "2015-09-09 06:06:48",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1985",
# "url": "",
#
# "author": [
# "Konrad Glund"
# ],
# "authors": [
#
# {"first" : "Konrad",	"last" : "Glund"}
# ],
#
# "dnbtitleid" : "860202984",
#
# "bibtexKey": "glund1985vakuolre"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2259dca36755d5b0cd80fac4e3a485254/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "259dca36755d5b0cd80fac4e3a485254",
# "interHash" : "6b62eac8b998351f4eefda31c03feb97",
# "label" : "CAM-Ausprägung in Plectranthus marrubioides Benth. (Fam. Laminaceae): Einfluss der Faktoren Licht, Blattemperatur, Luftfeuchtigkeit, Bodenwasserverfügbarkeit und Blattwasserzustand",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:28:44",
# "changeDate" : "2015-09-09 08:28:44",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1989",
# "url": "",
#
# "author": [
# "Werner Herppich"
# ],
# "authors": [
#
# {"first" : "Werner",	"last" : "Herppich"}
# ],
#
# "dnbtitleid" : "891547835",
#
# "bibtexKey": "herppich1989camausprgung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e49d4de272be8c4d6003f87f7393566c/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Asteraceae","merged:rwst"
# ],
#
# "intraHash" : "e49d4de272be8c4d6003f87f7393566c",
# "interHash" : "7c932914a59db9d31e641fdf6bed9674",
# "label" : "Zur Kenntnis der Apogamie in der Gattung Hieracium",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:11",
# "count" : 1,
# "pub-type": "article",
# "journal": "Berichte der Deutsch. Botan. Gesellsch.",
# "year": "1904",
# "url": "",
#
# "author": [
# "C. Ostenfeld"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Ostenfeld"}
# ],
# "volume": "XXII","pages": "376",
# "bibtexKey": "O"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e612e5827e1797ee70bfd9a7af45bc2c/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "e612e5827e1797ee70bfd9a7af45bc2c",
# "interHash" : "b3332335d4814e15d8f7654dd35cbc24",
# "label" : "Der Einfluß von Phytohormonen (Auxin, Kinetin und Gibberellinsäure) auf den Photosyntheseapparat und den Nitrat-Stoffwechsel von Sinapis alba",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 09:28:59",
# "changeDate" : "2015-09-08 09:28:59",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1980",
# "url": "",
#
# "author": [
# "Rainer Zerbe"
# ],
# "authors": [
#
# {"first" : "Rainer",	"last" : "Zerbe"}
# ],
#
# "dnbtitleid" : "213069911",
#
# "bibtexKey": "zerbe1980einflu"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2ee8b361c206fd1154054611676dac11c/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Poaceae","merged:rwst"
# ],
#
# "intraHash" : "ee8b361c206fd1154054611676dac11c",
# "interHash" : "96922e82e1e7b17df30eb31aa9c1fe89",
# "label" : "Bastarde zwischen Maisrassen, mit besonderer Berücksichtigung der Xenien",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:10",
# "count" : 1,
# "pub-type": "article",
# "journal": "Bibliotheca botanica",
# "year": "1901",
# "url": "",
#
# "author": [
# "C. Correns"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Correns"}
# ],
# "number": "53",
# "bibtexKey": "c05"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2c4cc7f489abd860c6710218b05116786/genealogie",
# "tags" : [
# "Botanik","Naturwissenschaften","Physik","merged:genealogie","Pflanzen_Botanik","Paläontologie","Kartographie","Biowissenschaften","Chemie","Astronomie","dnb","Geowissenschaften","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "c4cc7f489abd860c6710218b05116786",
# "interHash" : "3dc4e5300d4f7f1b13f7da8c7a90438b",
# "label" : "Comparative analysis of light controlled growth in light and dark grown Sinapis alba L",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:31:56",
# "changeDate" : "2015-09-09 03:31:56",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Christopher John Beggs"
# ],
# "authors": [
#
# {"first" : "Christopher John",	"last" : "Beggs"}
# ],
#
# "dnbtitleid" : "810620030",
#
# "bibtexKey": "beggs1981comparative"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/252f025ae975dee0b57fbc427a606ad51/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "52f025ae975dee0b57fbc427a606ad51",
# "interHash" : "ef7302160f8a52bae9b132741705c570",
# "label" : "Der Entwicklungszyklus von Typhula incarnata Lasch ex Fr: feinstrukturelle u. funktionelle Aspekte",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:22:57",
# "changeDate" : "2015-09-09 05:22:57",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Berthold Metzler"
# ],
# "authors": [
#
# {"first" : "Berthold",	"last" : "Metzler"}
# ],
#
# "dnbtitleid" : "841061092",
#
# "bibtexKey": "metzler1984entwicklungszyklus"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/27c8b18c34201ec453f752564ecbdea88/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "7c8b18c34201ec453f752564ecbdea88",
# "interHash" : "e5616af222aff208e19bc7861eff2225",
# "label" : "Vergleichende Untersuchungen zur Entwicklung und Degeneration der Arbuskeln von Glomus fasciculatum (Thaxter sensu Gerd.) Gerd. & und Trappe (Endogonaceae) in den Wurzeln von Avena sativa L., Allium cepa L., Solanum lycopersicum L. und Phaseolus vulgaris L.",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:54:06",
# "changeDate" : "2015-09-09 07:54:06",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Tom Alexander"
# ],
# "authors": [
#
# {"first" : "Tom",	"last" : "Alexander"}
# ],
#
# "dnbtitleid" : "890292655",
#
# "bibtexKey": "alexander1987vergleichende"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/21a9b8e7a4fa10acf69d90927f0c28cc2/genealogie",
# "tags" : [
# "Jugendpflege","Erziehung","Schul_und_Bildungswesen","dnb","merged:genealogie","Unterricht"
# ],
#
# "intraHash" : "1a9b8e7a4fa10acf69d90927f0c28cc2",
# "interHash" : "b4e740ef51b3d1081ae68fb3099ab778",
# "label" : "Zur Erhöhung der Effektivität des Unterrichts bei der Einführung der Schüler in die Botanik",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 02:37:44",
# "changeDate" : "2015-09-09 02:37:44",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1977",
# "url": "",
#
# "author": [
# "Rainer Krohn"
# ],
# "authors": [
#
# {"first" : "Rainer",	"last" : "Krohn"}
# ],
#
# "dnbtitleid" : "790982943",
#
# "bibtexKey": "krohn1977erhhung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2430044de7ab929b0792ae773c1b5c8c7/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "430044de7ab929b0792ae773c1b5c8c7",
# "interHash" : "890fa8ac6a582bc133a371976a404cf6",
# "label" : "Der Briza-Komplex in Südamerika: Briza, Calotheca, Chascolytrum, Poidium (Gramineae): e. Revision",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 07:29:07",
# "changeDate" : "2015-09-08 07:29:07",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1972",
# "url": "",
#
# "author": [
# "Oscar Matthei"
# ],
# "authors": [
#
# {"first" : "Oscar",	"last" : "Matthei"}
# ],
#
# "dnbtitleid" : "208375333",
#
# "bibtexKey": "matthei1972brizakomplex"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2f8131403f490661d1b5d1c55d21e9519/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "f8131403f490661d1b5d1c55d21e9519",
# "interHash" : "978e82396c03b37895e9b0d1faf168e9",
# "label" : "Untersuchungen zur molekularen Grundlage von Resistenz im Weizen-Schwarzrost-System (Triticum spec. - Puccinia graminis f. sp. tritici)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:03:26",
# "changeDate" : "2015-09-09 06:03:26",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1985",
# "url": "",
#
# "author": [
# "Karl-Heinz Kogel"
# ],
# "authors": [
#
# {"first" : "Karl-Heinz",	"last" : "Kogel"}
# ],
#
# "dnbtitleid" : "860103242",
#
# "bibtexKey": "kogel1985untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/21b374fe6c4e2d83f199e6e79868775fb/genealogie",
# "tags" : [
# "dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "1b374fe6c4e2d83f199e6e79868775fb",
# "interHash" : "85af732ac2cbc2ac9ec432529490f91e",
# "label" : "Geschichte der Botanik in Jena von der Gründung der Universität bis zur Goethezeit",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-07 22:52:52",
# "changeDate" : "2015-09-07 22:52:52",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1963",
# "url": "",
#
# "author": [
# "Ilse Jahn"
# ],
# "authors": [
#
# {"first" : "Ilse",	"last" : "Jahn"}
# ],
#
# "editor": [
# "Nicolas Robin"
# ],
# "editors": [
#
# {"first" : "Nicolas",	"last" : "Robin"}
# ],
#
# "dnbtitleid" : "1009232959",
#
# "bibtexKey": "jahn1963geschichte"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/230138b7936cb1dd2f682b24980b4b896/genealogie",
# "tags" : [
# "Botanik","Naturwissenschaften","Physik","merged:genealogie","Pflanzen_Botanik","Paläontologie","Kartographie","Biowissenschaften","Chemie","Astronomie","dnb","Geowissenschaften","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "30138b7936cb1dd2f682b24980b4b896",
# "interHash" : "505bfab048c25b78f6a7be1ecfccb43c",
# "label" : "Reaktionen von Fontinalis antipyretica Hedw. nach experimentellen Belastungen mit Schwermetallverbindungen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:37:59",
# "changeDate" : "2015-09-09 03:37:59",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Curt Henrique Sommer"
# ],
# "authors": [
#
# {"first" : "Curt Henrique",	"last" : "Sommer"}
# ],
#
# "dnbtitleid" : "810819058",
#
# "bibtexKey": "sommer1981reaktionen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2fee081997fc9e148f03539e028a55271/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "fee081997fc9e148f03539e028a55271",
# "interHash" : "187aecb4cdda96171d5007322e8ba416",
# "label" : "Untersuchungen zu Aminosäurestoffwechsel und Nikkomycinbildung in Streptomyces tendae",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:20:10",
# "changeDate" : "2015-09-09 06:20:10",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Birgit Jordan"
# ],
# "authors": [
#
# {"first" : "Birgit",	"last" : "Jordan"}
# ],
#
# "dnbtitleid" : "860729850",
#
# "bibtexKey": "jordan1986untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/266c16acbab7031ffad28f54dd066e5df/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Umweltschutz","Landschaftsgestaltung","Raumordnung","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "66c16acbab7031ffad28f54dd066e5df",
# "interHash" : "5426e53909a764d88ffcd5f30d0de217",
# "label" : "Einfluss von Sulfit auf ausgewählte Bereiche des Aminosäurestoffwechsels bei der Flechtenalge Trebouxia spec",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:16:43",
# "changeDate" : "2015-09-09 04:16:43",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Dietrich Ewald"
# ],
# "authors": [
#
# {"first" : "Dietrich",	"last" : "Ewald"}
# ],
#
# "dnbtitleid" : "821140698",
#
# "bibtexKey": "ewald1982einfluss"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/26b0cc0d3ea322cc24d80d1ce9b446137/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Asteraceae","merged:rwst"
# ],
#
# "intraHash" : "6b0cc0d3ea322cc24d80d1ce9b446137",
# "interHash" : "81ed8f38d7e0aa65a86aa2ad8de0caac",
# "label" : "Kastrerings forsøg med Hieracium og andre Cichorieae",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:11",
# "count" : 1,
# "pub-type": "article",
# "journal": "Botanisk Tidsskrift",
# "year": "1903",
# "url": "",
#
# "author": [
# "C. Ostenfeld"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Ostenfeld"}
# ],
# "volume": "25",
# "bibtexKey": "OR"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25b2ed08af50507319f3399ce3949fb4b/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "5b2ed08af50507319f3399ce3949fb4b",
# "interHash" : "7f17108ef9c52c57ef13429563be0d34",
# "label" : "Zum Metabolismus der Indol-3-Essigsäure Indol-Essigsäure in gesunden und Rostpilz-infizierten Weizenblättern",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:37:45",
# "changeDate" : "2015-09-09 06:37:45",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Gertrud Wiese"
# ],
# "authors": [
#
# {"first" : "Gertrud",	"last" : "Wiese"}
# ],
#
# "dnbtitleid" : "870112449",
#
# "bibtexKey": "wiese1986metabolismus"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2abca9b751de03d8e75b706111082160f/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "abca9b751de03d8e75b706111082160f",
# "interHash" : "780af2577d2586f384b38de60099343a",
# "label" : "Zur Kontrolle der Fettsäure- und Glycerolipidsynthese isolierter Spinatchloroplasten",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:23:10",
# "changeDate" : "2015-09-09 05:23:10",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1983",
# "url": "",
#
# "author": [
# "Andreas Sauer"
# ],
# "authors": [
#
# {"first" : "Andreas",	"last" : "Sauer"}
# ],
#
# "dnbtitleid" : "841064946",
#
# "bibtexKey": "sauer1983kontrolle"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/26fb1d089bbf9596835c3b965053e8619/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "6fb1d089bbf9596835c3b965053e8619",
# "interHash" : "b5ca4d1c68ea56bb49189e3741d27482",
# "label" : "Untersuchungen zu Entwicklung und Eigenschaften von Lipasen und Glyoxysomen in reifenden und keimenden Ölsamen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:52:37",
# "changeDate" : "2015-09-09 03:52:37",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Anton Fusseder"
# ],
# "authors": [
#
# {"first" : "Anton",	"last" : "Fusseder"}
# ],
#
# "dnbtitleid" : "820209880",
#
# "bibtexKey": "fusseder1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/24f5c38fec605e03635d5a227cc5d51ed/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "4f5c38fec605e03635d5a227cc5d51ed",
# "interHash" : "60789a80bf10fcdfae864309cd02f0a2",
# "label" : "Systematische und ökologische Studien zur Bestandsaufnahme der Foraminiferenfauna um Helgoland in Abhängigkeit vom Jahresgang",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:16:44",
# "changeDate" : "2015-09-09 07:16:44",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Renate Küppers"
# ],
# "authors": [
#
# {"first" : "Renate",	"last" : "Küppers"}
# ],
#
# "dnbtitleid" : "880191740",
#
# "bibtexKey": "kuppers1987systematische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/281bf9600ad704187df595d0979465062/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "81bf9600ad704187df595d0979465062",
# "interHash" : "30b8f9368e99b0df4cbeecfa09ec1f42",
# "label" : "Charakterisierung und immuncytochemische Lokalisierung von Phosphorylase-Formen aus Spinat-Blättern",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:59:13",
# "changeDate" : "2015-09-09 04:59:13",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1983",
# "url": "",
#
# "author": [
# "Christoph Schächtele"
# ],
# "authors": [
#
# {"first" : "Christoph",	"last" : "Schächtele"}
# ],
#
# "dnbtitleid" : "840224559",
#
# "bibtexKey": "schachtele1983charakterisierung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e29248561f5a0c19a811cb055a4e17d6/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "e29248561f5a0c19a811cb055a4e17d6",
# "interHash" : "cf3f8c0287233a27242f1d059099a581",
# "label" : "Einfluss eines verringerten Wasserpotentials bei verschiedenen Lichtintensitäten auf Wachstum und Akkumulation von Prolin und MDA bei Keimpflanzen von Hafer und Mais",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:01:22",
# "changeDate" : "2015-09-09 08:01:22",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Hanan Hamami"
# ],
# "authors": [
#
# {"first" : "Hanan",	"last" : "Hamami"}
# ],
#
# "dnbtitleid" : "890631913",
#
# "bibtexKey": "hamami1988einfluss"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/297269804b1653c137f2227c23a8c91ee/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Asteraceae","Biologie","merged:rwst"
# ],
#
# "intraHash" : "97269804b1653c137f2227c23a8c91ee",
# "interHash" : "e552347d3b771fc3cf6a746621f7bc14",
# "label" : "Weitere Beiträge zur Fruchtentwicklung bei der Gattung Hieracium",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:11",
# "count" : 1,
# "pub-type": "article",
# "journal": "Berichte der Deutsch. Botan. Gesellsch.",
# "year": "1904",
# "url": "",
#
# "author": [
# "C. Ostenfeld"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Ostenfeld"}
# ],
# "volume": "XXII","pages": "537",
# "bibtexKey": "O1"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d18f481a27d8a71081410533226f403d/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "d18f481a27d8a71081410533226f403d",
# "interHash" : "67be2a3260d548314a3780de7b9e0225",
# "label" : "Entwicklung eines Testes mit bewurzelten Blättern von Solanum tuberosum L. zur Ermittlung von Aufnahme und Transport blattapplizierter Substanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:40:46",
# "changeDate" : "2015-09-09 08:40:46",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Gottfried Baier"
# ],
# "authors": [
#
# {"first" : "Gottfried",	"last" : "Baier"}
# ],
#
# "dnbtitleid" : "900074280",
#
# "bibtexKey": "baier1987entwicklung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/296d820657985c56dc3f86e378e92ea3b/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin"
# ],
#
# "intraHash" : "96d820657985c56dc3f86e378e92ea3b",
# "interHash" : "3d7d2268e99d224f0610fd13aeea1318",
# "label" : "Untersuchungen zum Vorkommen und zum Gehalt Wuchsstoff-ähnlicher Substanzen in verschiedenen Entwicklungsstadien der Kulturkarotte (Daucus carota L.)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:42:19",
# "changeDate" : "2015-09-09 04:42:19",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Klaus Palussek"
# ],
# "authors": [
#
# {"first" : "Klaus",	"last" : "Palussek"}
# ],
#
# "dnbtitleid" : "830833625",
#
# "bibtexKey": "palussek1982untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2501a79f6df067991725da4d87b2209ca/twiebke",
# "tags" : [
# "imported","merged:twiebke"
# ],
#
# "intraHash" : "501a79f6df067991725da4d87b2209ca",
# "interHash" : "7eae6ad2d14b070203cc86e5f0b4d137",
# "label" : "Skript zum Vertiefungsstudium Botanik/Forstnutzung, Einführung in\n\tdie Aboristik und Baumpflege für StudentInnen der Forstwissenschaften\n\tin Tharandt",
# "user" : "twiebke",
# "description" : "",
# "date" : "2012-01-19 14:03:07",
# "changeDate" : "2012-01-19 14:03:07",
# "count" : 1,
# "pub-type": "techreport",
#
# "year": "2004",
# "url": "",
#
# "author": [
# "Claus-Thomas Bues, Prof. Dr. Dr. habil."
# ],
# "authors": [
#
# {"first" : "Claus-Thomas",	"last" : "Bues, Prof. Dr. Dr. habil."}
# ],
#
# "owner" : "torsten",
#
# "bibtexKey": "Skript"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/26a09a976585bed7fdbf6b8b263b999db/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "6a09a976585bed7fdbf6b8b263b999db",
# "interHash" : "76a2b32fbfd9923759cd4ae4b7ceb4f6",
# "label" : "Manipulation individueller Zellen der Nutzpflanze Brassica napus L. mit Hilfe von Elektrofusion, Zellrekonstruktion und Mikroinjektion",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:19:21",
# "changeDate" : "2015-09-09 07:19:21",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Germán Spangenberg"
# ],
# "authors": [
#
# {"first" : "Germán",	"last" : "Spangenberg"}
# ],
#
# "dnbtitleid" : "880318171",
#
# "bibtexKey": "spangenberg1986manipulation"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2818732b67cd553bbfc52fa8d16302b32/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "818732b67cd553bbfc52fa8d16302b32",
# "interHash" : "7fec020f685109ab12c9e18852fa5c1b",
# "label" : "Nachweis und Charakterisierung durch Chalkonsynthase unter Verwendung definierter Genotypen höherer Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 09:30:51",
# "changeDate" : "2015-09-08 09:30:51",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Rgine Spribille","Regine Spribille"
# ],
# "authors": [
#
# {"first" : "Rgine",	"last" : "Spribille"},
# {"first" : "Regine",	"last" : "Spribille"}
# ],
#
# "dnbtitleid" : "213100746",
#
# "bibtexKey": "spribille1982nachweis"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2222400bed32696863265fb9dfd829521/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "222400bed32696863265fb9dfd829521",
# "interHash" : "2e17ad47a72e50612a06a85326d21a8d",
# "label" : "Biochemische Resistenzmechanismen von Sojabohne (Glycine max L.) gegenüber Phytophthora megasperma f.sp. glycinea",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:48:46",
# "changeDate" : "2015-09-09 07:48:46",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Anne Bonhoff"
# ],
# "authors": [
#
# {"first" : "Anne",	"last" : "Bonhoff"}
# ],
#
# ...
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:56:27",
# "changeDate" : "2015-09-09 05:56:27",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1985",
# "url": "",
#
# "author": [
# "Bernhard Eugen Nickl"
# ],
# "authors": [
#
# {"first" : "Bernhard Eugen",	"last" : "Nickl"}
# ],
#
# "dnbtitleid" : "850929172",
#
# "bibtexKey": "nickl1985steuerung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/23fe5d19a2878ab00d6821f59492fdf25/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "3fe5d19a2878ab00d6821f59492fdf25",
# "interHash" : "5899b386c6d7ae417d9738b58b1eecf1",
# "label" : "Beiträge zur Taxonomie der Gattung Galinsoga R. et P. (Asteraceae, Heliantheae, Galinsoginae)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:44:49",
# "changeDate" : "2015-09-09 04:44:49",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Dorothea Schulz"
# ],
# "authors": [
#
# {"first" : "Dorothea",	"last" : "Schulz"}
# ],
#
# "dnbtitleid" : "830930078",
#
# "bibtexKey": "schulz1981beitrge"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2623462f3ca86d80afecc0e0d1f0a14b8/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "623462f3ca86d80afecc0e0d1f0a14b8",
# "interHash" : "b9fb15793637b9b8a50b82a3377a9fc3",
# "label" : "Untersuchungen zur Beteiligung von Ethylen und Gibberellinen an pflanzlichen Entwicklungsprozessen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:54:42",
# "changeDate" : "2015-09-09 06:54:42",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Daniela Kriechbaum"
# ],
# "authors": [
#
# {"first" : "Daniela",	"last" : "Kriechbaum"}
# ],
#
# "dnbtitleid" : "870813153",
#
# "bibtexKey": "kriechbaum1986untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2b3c5fa2162d14482e39b1bfcf703e7e7/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "b3c5fa2162d14482e39b1bfcf703e7e7",
# "interHash" : "06872f5438c60cd9a378e1b8c3d8056c",
# "label" : "Untersuchungen zur Mobilität von Xenobiotika in höheren Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:38:07",
# "changeDate" : "2015-09-09 04:38:07",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Stefanie Neumann"
# ],
# "authors": [
#
# {"first" : "Stefanie",	"last" : "Neumann"}
# ],
#
# "dnbtitleid" : "830669388",
#
# "bibtexKey": "neumann1982untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d05166e2c6beb03866be57a74d27011a/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "d05166e2c6beb03866be57a74d27011a",
# "interHash" : "de42db069554bbea46a46014bfe009de",
# "label" : "Zur Wirkungsweise von NOPflanzen: vergl. Untersuchungen im akuten u. chron. Bereich",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 08:55:53",
# "changeDate" : "2015-09-08 08:55:53",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Elke Boschke"
# ],
# "authors": [
#
# {"first" : "Elke",	"last" : "Boschke"}
# ],
#
# "dnbtitleid" : "212370510",
#
# "bibtexKey": "boschke1984wirkungsweise"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/294486a5c026d2431c048df159133dbf9/genealogie",
# "tags" : [
# "Garten","Biowissenschaften","Botanik","Landwirtschaft","Umweltschutz","Landschaftsgestaltung","Raumordnung","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "94486a5c026d2431c048df159133dbf9",
# "interHash" : "71402c54469912badf9e2ddf7bf98263",
# "label" : "Wasserhaushaltsparameter von Paprikafruchtzellen und die toxische Wirkung von Umweltchemikalien",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:51:20",
# "changeDate" : "2015-09-09 05:51:20",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Joachim Rygol"
# ],
# "authors": [
#
# {"first" : "Joachim",	"last" : "Rygol"}
# ],
#
# "dnbtitleid" : "850790670",
#
# "bibtexKey": "rygol1984wasserhaushaltsparameter"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2bcc643b6b7618d1c94bd276170592fd9/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "bcc643b6b7618d1c94bd276170592fd9",
# "interHash" : "f8405a606d5cc474706c79f0b390f1ff",
# "label" : "In-vitro-Regeneration der Erbse (Pisum sativum) über die somatische Embryogenese",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:50:07",
# "changeDate" : "2015-09-09 07:50:07",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Wilfried Kysely"
# ],
# "authors": [
#
# {"first" : "Wilfried",	"last" : "Kysely"}
# ],
#
# "dnbtitleid" : "890076251",
#
# "bibtexKey": "kysely1988invitroregeneration"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2726671b79dd9a502ab09d5bf65284a82/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "726671b79dd9a502ab09d5bf65284a82",
# "interHash" : "361c1e1d5288fb10ff1cc4b0b75bc343",
# "label" : "Zur Morphologie, Phylogenie und Systematik der Gattung Dalechampia L. (Euphorbiaceae): unter bes. Berücks. d. reproduktiv-pollinativen Bereiches",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 08:44:27",
# "changeDate" : "2015-09-08 08:44:27",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Norbert Magin"
# ],
# "authors": [
#
# {"first" : "Norbert",	"last" : "Magin"}
# ],
#
# "dnbtitleid" : "212196561",
#
# "bibtexKey": "magin1986morphologie"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/288fda738e1ccf880042ebe1066ac0ce8/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "88fda738e1ccf880042ebe1066ac0ce8",
# "interHash" : "9bf9efdf19f02fe8051993767151d7af",
# "label" : "Biochemische Charakterisierung von Wildtypen, Mutanten und Fusionshybriden von Pichia guilliermondii",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:13:52",
# "changeDate" : "2015-09-09 04:13:52",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Martina Hartung"
# ],
# "authors": [
#
# {"first" : "Martina",	"last" : "Hartung"}
# ],
#
# "dnbtitleid" : "821046837",
#
# "bibtexKey": "hartung1982biochemische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/215ab7263d3cff09b0d63c69c366af563/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "15ab7263d3cff09b0d63c69c366af563",
# "interHash" : "bd1cd7f1430dc70c890bb4ad23a5ea0b",
# "label" : "Die Wirkungen verschiedener Elicitoren und deren mögliche Bedeutung in Wirt/Pathogen-Beziehungen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:20:50",
# "changeDate" : "2015-09-09 05:20:50",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Harald Köhle"
# ],
# "authors": [
#
# {"first" : "Harald",	"last" : "Köhle"}
# ],
#
# "dnbtitleid" : "840998163",
#
# "bibtexKey": "kohle1984wirkungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/261d9a76f96775e12ca7a3832847d4ea4/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "61d9a76f96775e12ca7a3832847d4ea4",
# "interHash" : "7a79411facc145db7dfe2df69e81910b",
# "label" : "Vergleichende Untersuchungen über die Wirkung extremer Temperaturen auf Biomembranen von Blattzellen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:14:17",
# "changeDate" : "2015-09-09 05:14:17",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1983",
# "url": "",
#
# "author": [
# "Regina Thebud-Lassak"
# ],
# "authors": [
#
# {"first" : "Regina",	"last" : "Thebud-Lassak"}
# ],
#
# "dnbtitleid" : "840822146",
#
# "bibtexKey": "thebudlassak1983vergleichende"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/211f516d7b4b0828809c90b3b0b4a88da/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Umweltschutz","Landschaftsgestaltung","Raumordnung","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "11f516d7b4b0828809c90b3b0b4a88da",
# "interHash" : "13a0a1c3dc5841b2c5bbc5c2ebe5c2ed",
# "label" : "Untersuchungen über die Wirkung von Thallium auf die Primärprozesse der Photosynthese grüner Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:42:15",
# "changeDate" : "2015-09-09 05:42:15",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Hans-Georg Wystrcil"
# ],
# "authors": [
#
# {"first" : "Hans-Georg",	"last" : "Wystrcil"}
# ],
#
# "dnbtitleid" : "850500516",
#
# "bibtexKey": "wystrcil1984untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2248825044d92fa577b4fa41d73a58943/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin"
# ],
#
# "intraHash" : "248825044d92fa577b4fa41d73a58943",
# "interHash" : "f8be861f362ae5cf724a62d1808fbd50",
# "label" : "Morphologische Analyse des Einflusses von Alar auf das Wachstum von Ackerbohnenpflanzen (Vicia faba L.)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:02:57",
# "changeDate" : "2015-09-09 04:02:57",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Hilda Moreno Tapia"
# ],
# "authors": [
#
# {"first" : "Hilda",	"last" : "Moreno Tapia"}
# ],
#
# "dnbtitleid" : "820625833",
#
# "bibtexKey": "morenotapia1981morphologische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d53417fcc26af1b075973d534718e0a8/genealogie",
# "tags" : [
# "Garten","Biowissenschaften","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Reisen","Biologie","Tiere_Zoologie","Geographie","Heimat_und_Länderkunde"
# ],
#
# "intraHash" : "d53417fcc26af1b075973d534718e0a8",
# "interHash" : "dd6b90c051d5c170931ed67a91620e6c",
# "label" : "Die Vegetation der Waldwege und ihre Korrelation zu den Waldgesellschaften in verschiedenen Landschaften Südwestdeutschlands",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:13:05",
# "changeDate" : "2015-09-09 07:13:05",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Burkhard Schall"
# ],
# "authors": [
#
# {"first" : "Burkhard",	"last" : "Schall"}
# ],
#
# "dnbtitleid" : "880024860",
#
# "bibtexKey": "schall1987vegetation"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/21b098a1ef8c7d88bb40da2a33e5e5efc/rwst",
# "tags" : [
# "biology","plant-families","Asteraceae","botanik","botany","Europa","Biologie","Welt","merged:rwst"
# ],
#
# "intraHash" : "1b098a1ef8c7d88bb40da2a33e5e5efc",
# "interHash" : "9b4deb83a77e4e3e10dcd9da26db80e4",
# "label" : "Biodiversity and ecogeography of wild Lactuca spp in some European countries",
# "user" : "rwst",
# "description" : "",
# "date" : "2009-08-04 11:51:07",
# "changeDate" : "2009-08-04 11:51:07",
# "count" : 1,
# "pub-type": "article",
# "journal": "Genetic Resources and Crop Evolution",
# "year": "2001",
# "url": "",
#
# "author": [
# "A. Lebeda","I. Doležalovà","E. Křístková","B. Mieslerová"
# ],
# "authors": [
#
# {"first" : "A.",	"last" : "Lebeda"},
# {"first" : "I.",	"last" : "Doležalovà"},
# {"first" : "E.",	"last" : "Křístková"},
# {"first" : "B.",	"last" : "Mieslerová"}
# ],
# "volume": "48","pages": "153--64",
# "bibtexKey": "ldkm2000"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/280b73409d4c949604552045afa3a879b/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "80b73409d4c949604552045afa3a879b",
# "interHash" : "e376f3fba85ea024900b3fb413d9b4d6",
# "label" : "Untersuchungen zur Differenzierung von Agropyron repens (L.) Beauv",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:08:51",
# "changeDate" : "2015-09-09 04:08:51",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Franz Güttel"
# ],
# "authors": [
#
# {"first" : "Franz",	"last" : "Güttel"}
# ],
#
# "dnbtitleid" : "820863513",
#
# "bibtexKey": "guttel1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/280856cdedd6f0adee7a62c426c1bcf6b/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "80856cdedd6f0adee7a62c426c1bcf6b",
# "interHash" : "6a7e9bd78cb9830500d7728b698847e2",
# "label" : "Einfluss von NaCl auf Wachstum und Stoffwechsel verschieden salztoleranter Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 10:24:11",
# "changeDate" : "2015-09-09 10:24:11",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1977",
# "url": "",
#
# "author": [
# "Albrecht Priebe"
# ],
# "authors": [
#
# {"first" : "Albrecht",	"last" : "Priebe"}
# ],
#
# "dnbtitleid" : "920258239",
#
# "bibtexKey": "priebe1977einfluss"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/286ed86852467b83cbcb040fa7cd8e006/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "86ed86852467b83cbcb040fa7cd8e006",
# "interHash" : "96c3681a625be96f4773de736cf06c0b",
# "label" : "Untersuchungen zur Bedeutung des Indol-3-Methylglucosinolat Metabolismus Indol-Methylglucosinolat-Metabolismus für die Indol-3-Essigsäure Biosynthese Indol-Essigsäure-Biosynthese in Plasmodiophora-brassicae-infiziertem Wurzelgewebe von Cruciferen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:24:36",
# "changeDate" : "2015-09-09 05:24:36",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Thomas Rausch"
# ],
# "authors": [
#
# {"first" : "Thomas",	"last" : "Rausch"}
# ],
#
# "dnbtitleid" : "841091005",
#
# "bibtexKey": "rausch1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25c713bbb4bc55e35b877a1d06584e794/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "5c713bbb4bc55e35b877a1d06584e794",
# "interHash" : "6e9ebc1bc26eb6ecae0c630d57435d16",
# "label" : "Der Vegetationskomplex der Sandtrockenrasen in der Westfälischen Bucht",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:39:27",
# "changeDate" : "2015-09-09 07:39:27",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Eckhard Schröder"
# ],
# "authors": [
#
# {"first" : "Eckhard",	"last" : "Schröder"}
# ],
#
# "dnbtitleid" : "881168688",
#
# "bibtexKey": "schroder1988vegetationskomplex"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/24097b4a6a5cfb1e3fae61ff0c06d88bd/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "4097b4a6a5cfb1e3fae61ff0c06d88bd",
# "interHash" : "03f9c879dd632651e584af2bd43db15d",
# "label" : "Der weibliche Zapfen von Pseudovoltzia liebeana und seine Bedeutung für die Phylogenie der Koniferen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 09:43:01",
# "changeDate" : "2015-09-08 09:43:01",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1966",
# "url": "",
#
# "author": [
# "Hans-Joachim Schweitzer"
# ],
# "authors": [
#
# {"first" : "Hans-Joachim",	"last" : "Schweitzer"}
# ],
#
# "dnbtitleid" : "213185458",
#
# "bibtexKey": "schweitzer1966weibliche"
#
# }
#
# ]
# }

# %%
with open('botanik.json','r') as botanik_infile:
    data = botanik_infile.readlines()
    for line in data:
        print(line.strip())
# Out:
# {
# "types" : {
# "Bookmark" : {
# "pluralLabel" : "Bookmarks"
# },
# "Publication" : {
# "pluralLabel" : "Publications"
# },
# "GoldStandardPublication" : {
# "pluralLabel" : "GoldStandardPublications"
# },
# "GoldStandardBookmark" : {
# "pluralLabel" : "GoldStandardBookmarks"
# },
# "Tag" : {
# "pluralLabel" : "Tags"
# },
# "User" : {
# "pluralLabel" : "Users"
# },
# "Sphere" : {
# "pluralLabel" : "Spheres"
# }
# },
#
# "properties" : {
# "count" : {
# "valueType" : "number"
# },
# "date" : {
# "valueType" : "date"
# },
# "changeDate" : {
# "valueType" : "date"
# },
# "url" : {
# "valueType" : "url"
# },
# "id" : {
# "valueType" : "url"
# },
# "tags" : {
# "valueType" : "item"
# },
# "user" : {
# "valueType" : "item"
# }
# },
#
# "items" : [
#
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/151a9bb7aadbb8f9cd7516d287ef842a/schmidt2",
# "tags" : [
# "from_android"
# ],
#
# "intraHash" : "151a9bb7aadbb8f9cd7516d287ef842a",
# "label" : "Weiden (Botanik) \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-06-02 23:46:33",
# "changeDate" : "2017-06-02 23:46:33",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Weiden_(Botanik)"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/279da9197ac94560b25d4fad31e097b0/schmidt2",
# "tags" : [
# "from_android"
# ],
#
# "intraHash" : "279da9197ac94560b25d4fad31e097b0",
# "label" : "Horst (Botanik) \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2018-05-01 18:28:10",
# "changeDate" : "2018-05-01 18:28:10",
# "count" : 1,
# "url" : "https://de.wikipedia.org/wiki/Horst_(Botanik)"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/6c693298cf621782f51ed684a92a576e/karinnadrowski",
# "tags" : [
# "spezbot","botanik","spezielle"
# ],
#
# "intraHash" : "6c693298cf621782f51ed684a92a576e",
# "label" : "Spezielle Botanik und funktionelle Biodiversität",
# "user" : "karinnadrowski",
# "description" : "",
# "date" : "2011-02-13 13:47:31",
# "changeDate" : "2011-02-13 13:47:31",
# "count" : 1,
# "url" : "http://alfresco.uni-leipzig.de/spezbot/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/eb7eebfa272a71cc44009253bcecfed2/schmidt2",
# "tags" : [
# "from_android"
# ],
#
# "intraHash" : "eb7eebfa272a71cc44009253bcecfed2",
# "label" : "Botanik - Wüstenpflanze erntet Wasser aus der Luft - Wissen - Süddeutsche.de",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2018-05-07 09:40:28",
# "changeDate" : "2018-05-07 09:40:28",
# "count" : 1,
# "url" : "http://www.sueddeutsche.de/wissen/botanik-wuestenpflanze-erntet-wasser-aus-der-luft-1.3021848"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/fa8e601741b670106589bbd019a32b5a/robingarcia",
# "tags" : [
# "Unsortierte_Lesezeichen"
# ],
#
# "intraHash" : "fa8e601741b670106589bbd019a32b5a",
# "label" : "Geschichte der Botanik - Springer",
# "user" : "robingarcia",
# "description" : "",
# "date" : "2017-03-17 10:34:41",
# "changeDate" : "2017-04-13 09:58:51",
# "count" : 1,
# "url" : "http://link.springer.com/book/10.1007/978-3-642-39400-3"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/54388ce4887fa8840f10338ad59ab1da/vascoda",
# "tags" : [
# "fachzugang","biowissenschaft","bibliothek","biologie","zoologie","vascoda","botanik","literaturrecherche"
# ],
#
# "intraHash" : "54388ce4887fa8840f10338ad59ab1da",
# "label" : "vascoda Fachzugang für Biologie",
# "user" : "vascoda",
# "description" : "(tags: zoologie fachzugang botanik biowissenschaft biologie)",
# "date" : "2009-02-18 15:13:07",
# "changeDate" : "2009-08-28 16:33:16",
# "count" : 2,
# "url" : "http://www.vascoda.de/vascoda?ID=CLD_26_305&LANGUAGE=de"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/54388ce4887fa8840f10338ad59ab1da/mhohlfeld",
# "tags" : [
# "fachzugang","biowissenschaft","bibliothek","biologie","zoologie","vascoda","botanik","literaturrecherche"
# ],
#
# "intraHash" : "54388ce4887fa8840f10338ad59ab1da",
# "label" : "vascoda Fachzugang für Biologie",
# "user" : "mhohlfeld",
# "description" : "(tags: zoologie fachzugang botanik biowissenschaft biologie)",
# "date" : "2009-02-18 15:13:07",
# "changeDate" : "2009-03-10 15:05:44",
# "count" : 2,
# "url" : "http://www.vascoda.de/vascoda?ID=CLD_26_305&LANGUAGE=de"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/229fcb50b6eba69fce31ed26b64ba52a/domgabfil",
# "tags" : [
# "pdf","langues","yiddish","référence","lexicologie","dictionnaires_bilingues","très_spécialisé"
# ],
#
# "intraHash" : "229fcb50b6eba69fce31ed26b64ba52a",
# "label" : "Plant Names in Yiddish (YIVO, 2005) [pdf]",
# "user" : "domgabfil",
# "description" : "Groundbreaking Yiddish-English botanical dictionary, draws on literary, scientific, linguistic and religious sources to document a wealth of Yiddish plant names\u2014including many dialectal and regional variants. It is an essential reference work for Yiddish speakers and readers, scholars, researchers, culinary and nature enthusiasts, historians, scientists, and linguists",
# "date" : "2010-12-17 17:39:57",
# "changeDate" : "2013-01-15 08:22:29",
# "count" : 1,
# "url" : "http://www.yivoinstitute.org/botanik/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/645a4f2b9b39d9e47787882994b776a6/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "645a4f2b9b39d9e47787882994b776a6",
# "label" : "Erbse \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:48:20",
# "changeDate" : "2017-05-21 09:35:53",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Erbse"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/05278648bb917ac7b32512f3b0c0e3e9/gvogeler",
# "tags" : [
# "Botanik","Naturwissenschaften","Digitalisierung","Padua","Herbar","Frühe_Neuzeit"
# ],
#
# "intraHash" : "05278648bb917ac7b32512f3b0c0e3e9",
# "label" : "IPSA - Imaginum Patavinae Scientiae Archivum",
# "user" : "gvogeler",
# "description" : "",
# "date" : "2012-07-30 07:57:32",
# "changeDate" : "2012-07-30 07:57:32",
# "count" : 1,
# "url" : "http://www.ipsa-project.org/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/0cdf9e0d06f2a9511369674cd76eb3ff/vascoda",
# "tags" : [
# "biowissenschaft","bibliothek","fachportal","metasuche","biologie","zoologie","vascoda","botanik","vifa","virtuellefachbibliothek","portal","literaturrecherche"
# ],
#
# "intraHash" : "0cdf9e0d06f2a9511369674cd76eb3ff",
# "label" : "vifabio -Die virtuelle Fachbibliothek Biologie",
# "user" : "vascoda",
# "description" : "In vifabio werden Katalogdaten, ausgewählte Internetquellen, Zeitschriften, Datenbanken und Volltextdokumente komfortabel auffindbar gemacht.",
# "date" : "2008-12-04 18:46:06",
# "changeDate" : "2009-08-28 16:33:19",
# "count" : 7,
# "url" : "http://www.vifabio.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/bd7bb9ed1b85ff38a39ddd0d56908516/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "bd7bb9ed1b85ff38a39ddd0d56908516",
# "label" : "Grüne Minze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:21:53",
# "changeDate" : "2017-05-21 09:37:29",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Gr%C3%BCne_Minze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/95667531404507793ebd636d8911b39e/continued",
# "tags" : [
# "Botanik","Film","samtig","Obst","Papers","Pfirsich","Haare","Flaum"
# ],
#
# "intraHash" : "95667531404507793ebd636d8911b39e",
# "label" : "Ever wonder about peach fuzz? [PDF]",
# "user" : "continued",
# "description" : "Waxiness of skin combined with hairs reduce water loss + affect charge of the surface",
# "date" : "2017-06-01 17:35:42",
# "changeDate" : "2017-06-12 17:02:38",
# "count" : 1,
# "url" : "http://www.plantphysiol.org/content/156/4/2098.full.pdf"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/f0058ce1a37507c791bcfdd823501fbc/schmidt2",
# "tags" : [
# "borken","incredible_edible","permaculture","botanik","plants","garden","essbare_stadt"
# ],
#
# "intraHash" : "f0058ce1a37507c791bcfdd823501fbc",
# "label" : "Essbare Stadt Borken - Internetauftritt des Vereins \"Essbare Stadt Borken\"",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:05:12",
# "changeDate" : "2017-05-21 09:40:16",
# "count" : 1,
# "url" : "https://www.essbare-stadt-borken.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e4eb357daa030a610e3f16d9aa8d0720/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "e4eb357daa030a610e3f16d9aa8d0720",
# "label" : "Tausendkornmasse \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-21 00:17:36",
# "changeDate" : "2017-05-21 09:35:23",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Tausendkornmasse"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e9142e23d989f7458e82820ba8d87c48/schmidt2",
# "tags" : [
# "transitiontown","permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "e9142e23d989f7458e82820ba8d87c48",
# "label" : "Transition Town Projekte 2016 | Transition Town Bielefeld",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:07:29",
# "changeDate" : "2017-05-21 09:39:09",
# "count" : 1,
# "url" : "http://www.ttbielefeld.de/node/28"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/6826ae3f314a2728cb951a3ea57655c1/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze","list_of"
# ],
#
# "intraHash" : "6826ae3f314a2728cb951a3ea57655c1",
# "label" : "Minzen \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:27:53",
# "changeDate" : "2017-05-21 09:37:06",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Minzen"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/2d777ffe7cae68cd6fb892f06f6341f2/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","baumrausch","innenstadtgarten","garden"
# ],
#
# "intraHash" : "2d777ffe7cae68cd6fb892f06f6341f2",
# "label" : "Baumrausch: Eröffnung der Innenstadtgärten 2015",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 21:57:09",
# "changeDate" : "2017-05-21 09:38:07",
# "count" : 1,
# "url" : "http://www.baumrausch.de/aktuelles/news-details/?tx_ttnews%5Btt_news%5D=100&tx_ttnews%5BbackPid%5D=6&cHash=b2e27d09436afcb51a08796af482f1fe"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/f4101d265079e7c03c816b447093c0d0/esistimfluss",
# "tags" : [
# "Botanik","Freizeit","Kiel","Mitgliedschaft","2020"
# ],
#
# "intraHash" : "f4101d265079e7c03c816b447093c0d0",
# "label" : "Mitgliedschaft Freundeskreis ",
# "user" : "esistimfluss",
# "description" : "",
# "date" : "2020-08-09 13:41:17",
# "changeDate" : "2020-08-09 13:41:17",
# "count" : 1,
# "url" : "http://www.butterbaum.uni-kiel.de/index.php/de/mitgliedschaft"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/0cdf9e0d06f2a9511369674cd76eb3ff/mhohlfeld",
# "tags" : [
# "metasuche","biologie","botanik","virtuellefachbibliothek","fachbibliothek","biowissenschaft","bibliothek","fachportal","zoologie","vascoda","vifa","portal","literaturrecherche"
# ],
#
# "intraHash" : "0cdf9e0d06f2a9511369674cd76eb3ff",
# "label" : "vifabio -Die virtuelle Fachbibliothek Biologie",
# "user" : "mhohlfeld",
# "description" : "In vifabio werden Katalogdaten, ausgewählte Internetquellen, Zeitschriften, Datenbanken und Volltextdokumente komfortabel auffindbar gemacht.",
# "date" : "2008-12-04 18:46:06",
# "changeDate" : "2009-03-10 15:05:47",
# "count" : 7,
# "url" : "http://www.vifabio.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/8b0f9b75d3d332d5d621077df5c4685b/nunatak",
# "tags" : [
# "botanik","bauen"
# ],
#
# "intraHash" : "8b0f9b75d3d332d5d621077df5c4685b",
# "label" : "baubotanik",
# "user" : "nunatak",
# "description" : "",
# "date" : "2012-04-29 21:11:15",
# "changeDate" : "2012-04-29 21:11:15",
# "count" : 1,
# "url" : "http://www.baubotanik.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/15d34f96778a2763d66c41c3a6d3d1e4/schmidt2",
# "tags" : [
# "bielefeld","transitiontown","permaculture","botanik","plants","garden"
# ],
#
# "intraHash" : "15d34f96778a2763d66c41c3a6d3d1e4",
# "label" : "Transition Town Bielefeld | Transition Town Bielefeld",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:05:35",
# "changeDate" : "2017-05-21 09:39:45",
# "count" : 1,
# "url" : "http://www.ttbielefeld.de/"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/8d5867cc0485b9417726588ca705f385/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "8d5867cc0485b9417726588ca705f385",
# "label" : "Nanaminze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:21:56",
# "changeDate" : "2017-05-21 09:37:18",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Nanaminze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/2810cc2d190da1b75662f74ff1714521/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "2810cc2d190da1b75662f74ff1714521",
# "label" : "Rundblättrige Minze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:30:13",
# "changeDate" : "2017-05-21 09:36:47",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Rundbl%C3%A4ttrige_Minze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/c465359be791b0c18cc4cb3dbcfd7ea9/schmidt2",
# "tags" : [
# "akademie","permaculture","botanik","plants","literatur","toexplore","garden"
# ],
#
# "intraHash" : "c465359be791b0c18cc4cb3dbcfd7ea9",
# "label" : "Permakultur Akademie: Infothek: Literatur: Literatur zur Permakultur",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 19:22:52",
# "changeDate" : "2017-05-21 09:38:33",
# "count" : 1,
# "url" : "https://permakultur-akademie.de/front_content.php?idcat=44&lang=1"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e76964733861eec4eb4033f8ebeac9d4/schmidt2",
# "tags" : [
# "permaculture","botanik","plants","garden","minze"
# ],
#
# "intraHash" : "e76964733861eec4eb4033f8ebeac9d4",
# "label" : "Acker-Minze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-20 23:16:17",
# "changeDate" : "2017-05-21 09:37:40",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Acker-Minze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/21895e0da2bcb8f39e259edc76ac3dfd/schmidt2",
# "tags" : [
# "bioindicator","gardening","biologie","botanik","zeigerpflanze"
# ],
#
# "intraHash" : "21895e0da2bcb8f39e259edc76ac3dfd",
# "label" : "Zeigerpflanze \u2013 Wikipedia",
# "user" : "schmidt2",
# "description" : "a bookmark",
# "date" : "2017-05-29 06:27:10",
# "changeDate" : "2017-06-09 16:50:08",
# "count" : 1,
# "url" : "https://de.m.wikipedia.org/wiki/Zeigerpflanze"
#
# }
# ,
# {
# "type" : "Bookmark",
# "id"   : "https://www.bibsonomy.org/url/e3c382be174816d25fbffe6185682cd9/lysander07",
# "tags" : [
# "rezension","biblionomicon","2012","frauen","biography"
# ],
#
# "intraHash" : "e3c382be174816d25fbffe6185682cd9",
# "label" : "BIBLIONOMICON: Verwegene Frauen - Liv Winterberg 'Vom anderen Ende der Welt'",
# "user" : "lysander07",
# "description" : "Rezension zu Liv Winterbergs Roman über das Leben der Jeanne Baré, die als Mann verkleidet an Entdeckungsfahrten in die Südsee teilnahm und als Wissenschaftlerin wertvolle Beiträge zur Botanik leistete....via Biblionomicon",
# "date" : "2012-01-23 13:54:43",
# "changeDate" : "2012-01-23 13:54:43",
# "count" : 1,
# "url" : "http://biblionomicon.blogspot.com/2012/01/verwegene-frauen-liv-winterberg-vom.html"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/229b8e5804a2b7e8dc98760dcf9511b54/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "29b8e5804a2b7e8dc98760dcf9511b54",
# "interHash" : "654e839263f94e4738888a527d5364b0",
# "label" : "Dynamik der Thylakoidmembran ergrünender Chlorella fusca g 2: Entwicklung von Ultrastruktur und Funktion des Photosyntheseapparates",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:54:57",
# "changeDate" : "2015-09-09 06:54:57",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Elisabeth Przibilla"
# ],
# "authors": [
#
# {"first" : "Elisabeth",	"last" : "Przibilla"}
# ],
#
# "dnbtitleid" : "870814451",
#
# "bibtexKey": "przibilla1986dynamik"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25364c8d0f8696590b2c77f1f54369c29/genealogie",
# "tags" : [
# "Botanik","Umweltschutz","Landschaftsgestaltung","Elektronik","Industrielle_und_handwerkliche_Fertigung","merged:genealogie","Fertigungstechnik","Ingenieurwissenschaften_und_Maschinenbau","Umwelttechnik","Energie-","Bautechnik","Raumordnung","Bergbau","dnb","Elektrotechnik","Energiewirtschaft","Maschinen"
# ],
#
# "intraHash" : "5364c8d0f8696590b2c77f1f54369c29",
# "interHash" : "2fce69f6d7e22e250e4105a8c9ced5f8",
# "label" : "Weiterentwicklung der Methoden und Daten zur Berechnung des Radionuklidtransportes von der Luft in die Pflanzen um kerntechnische Anlagen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:28:16",
# "changeDate" : "2015-09-09 05:28:16",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Margot Horn"
# ],
# "authors": [
#
# {"first" : "Margot",	"last" : "Horn"}
# ],
#
# "dnbtitleid" : "850076021",
#
# "bibtexKey": "horn1984weiterentwicklung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2806c8900b42892c085142102ee2e881e/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "806c8900b42892c085142102ee2e881e",
# "interHash" : "d131194a872de421ccdecb348ca7e8de",
# "label" : "Induktion von Chloramphenicol-Resistenz und interspezifischem Organelltransfer bei Nicotiana plumbaginifolia in Zellkulturen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:44:03",
# "changeDate" : "2015-09-09 05:44:03",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Roswitha Golling"
# ],
# "authors": [
#
# {"first" : "Roswitha",	"last" : "Golling"}
# ],
#
# "dnbtitleid" : "850535824",
#
# "bibtexKey": "golling1984induktion"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2f3bbc635b3e7a40ee8ce7ec8e89c9176/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","Land_und_Forstwirtschaft","dnb","merged:genealogie","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "f3bbc635b3e7a40ee8ce7ec8e89c9176",
# "interHash" : "986cd940ea5eff184a5f1d5941d94f66",
# "label" : "Die Pathogenese des Pezicula-Krebses der amerikanischen Roteiche (Quercus rubra L.), verursacht durch Pezicula cinnamomea (DC.) Sacc., im Vergleich mit anderen Rindenerkrankungen der Eiche",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:19:41",
# "changeDate" : "2015-09-09 08:19:41",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1989",
# "url": "",
#
# "author": [
# "Rolf Dieter Kehr"
# ],
# "authors": [
#
# {"first" : "Rolf Dieter",	"last" : "Kehr"}
# ],
#
# "dnbtitleid" : "891271481",
#
# "bibtexKey": "kehr1989pathogenese"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25e4bd2c95f4ca7c97d22ea203fbbb85e/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "5e4bd2c95f4ca7c97d22ea203fbbb85e",
# "interHash" : "3607bdb262ef58572eefaf129508a984",
# "label" : "Die chilenischen Arten der Gattung Sisyrinchium L. (Iridaceae)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:07:15",
# "changeDate" : "2015-09-09 07:07:15",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Roberto Rodríguez Rios"
# ],
# "authors": [
#
# {"first" : "Roberto",	"last" : "Rodríguez Rios"}
# ],
#
# "dnbtitleid" : "871322692",
#
# "bibtexKey": "rodriguezrios1986chilenischen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2197c71747753a68ef3d7e06188ab19ef/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "197c71747753a68ef3d7e06188ab19ef",
# "interHash" : "8904da62bda88062abb9d7ec20508683",
# "label" : "Physiologische und biochemische Untersuchungen an dem Cyanellen enthaltenden Flagellat Cyanophora paradoxa und an Rhopalodia gibba, einer Diatomee mit blau-grünen Einschlüssen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:20:52",
# "changeDate" : "2015-09-09 04:20:52",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Liliane Floener"
# ],
# "authors": [
#
# {"first" : "Liliane",	"last" : "Floener"}
# ],
#
# "dnbtitleid" : "830021108",
#
# "bibtexKey": "floener1982physiologische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d96b6c1317b47237ac51b061fd2ce178/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "d96b6c1317b47237ac51b061fd2ce178",
# "interHash" : "14bd4269e150a36b6cf548b6e701d56e",
# "label" : "Stoffwechselphysiologische Untersuchungen zum Problem der obligaten Phototrophie bei der volvocalen Grünalge Chlamydobotrys stellata",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:02:30",
# "changeDate" : "2015-09-09 04:02:30",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Edgar Luck"
# ],
# "authors": [
#
# {"first" : "Edgar",	"last" : "Luck"}
# ],
#
# "dnbtitleid" : "820595128",
#
# "bibtexKey": "luck1981stoffwechselphysiologische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2be1c69598eadd4b2976ae22c03677715/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "be1c69598eadd4b2976ae22c03677715",
# "interHash" : "05fdc7807eb02226b8f0c5ea9de832b0",
# "label" : "Untersuchungen zur Charakterisierung und Regulation der 3-Hydroxy-3-methylglutaryl-Coenzym-A-Reduktase Hydroxy-methylglutaryl-Coenzym-A-Reduktase (Mevalonat: NADP_1hn+ NADP Oxidoreduktase, CoA acylierend, E.C. 1.1.1.34 eins eins eins vierunddreissig) in Keimlingen von Raphanus sativus",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:50:41",
# "changeDate" : "2015-09-09 03:50:41",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Thomas Bach"
# ],
# "authors": [
#
# {"first" : "Thomas",	"last" : "Bach"}
# ],
#
# "dnbtitleid" : "820146870",
#
# "bibtexKey": "bach1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2b76c67bdb6755d33695a0ef952a44bc3/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "b76c67bdb6755d33695a0ef952a44bc3",
# "interHash" : "5f7bc6473b65cf1ca2397aa023a78fd1",
# "label" : "Sensorische und gaschromatographische Untersuchungen zum off-Flavour von Ackerbohnensamen und -proteinisolat: e. Beitr. zur Subjektiven Gustometrie u. Olfaktometrie#1hn,#1hn, u. zur Reaktionskinetik sensor. Veränderungen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 10:08:38",
# "changeDate" : "2015-09-08 10:08:38",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1976",
# "url": "",
#
# "author": [
# "Ulf Seidel"
# ],
# "authors": [
#
# {"first" : "Ulf",	"last" : "Seidel"}
# ],
#
# "dnbtitleid" : "213364700",
#
# "bibtexKey": "seidel1976sensorische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e6aee650c2970015e01dcbfaa606847f/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "e6aee650c2970015e01dcbfaa606847f",
# "interHash" : "fc569922004c7326dbecb904bf548a28",
# "label" : "Toleranzmechanismen von Flechten gegenüber natürlicher und anthropogener Belastung: In-vivo-Chloroplastenfluoreszenz als charakteristisches Kriterium und Grundlage für ein Stress-Reaktionsmodell",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:21:41",
# "changeDate" : "2015-09-09 07:21:41",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Hans-Joachim Lühmann"
# ],
# "authors": [
#
# {"first" : "Hans-Joachim",	"last" : "Lühmann"}
# ],
#
# "dnbtitleid" : "880401400",
#
# "bibtexKey": "luhmann1987toleranzmechanismen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2a42e94098d6d65d9bd99a0c3522ab236/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "a42e94098d6d65d9bd99a0c3522ab236",
# "interHash" : "78ceb90ca3aed274a5302efbf3b3bb2a",
# "label" : "Das vakuoläre System aus Zellsuspensionskulturen der Tomate (Lycopersicon esculentum): Isolierung u. Charakterisierung",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:06:48",
# "changeDate" : "2015-09-09 06:06:48",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1985",
# "url": "",
#
# "author": [
# "Konrad Glund"
# ],
# "authors": [
#
# {"first" : "Konrad",	"last" : "Glund"}
# ],
#
# "dnbtitleid" : "860202984",
#
# "bibtexKey": "glund1985vakuolre"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2259dca36755d5b0cd80fac4e3a485254/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "259dca36755d5b0cd80fac4e3a485254",
# "interHash" : "6b62eac8b998351f4eefda31c03feb97",
# "label" : "CAM-Ausprägung in Plectranthus marrubioides Benth. (Fam. Laminaceae): Einfluss der Faktoren Licht, Blattemperatur, Luftfeuchtigkeit, Bodenwasserverfügbarkeit und Blattwasserzustand",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:28:44",
# "changeDate" : "2015-09-09 08:28:44",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1989",
# "url": "",
#
# "author": [
# "Werner Herppich"
# ],
# "authors": [
#
# {"first" : "Werner",	"last" : "Herppich"}
# ],
#
# "dnbtitleid" : "891547835",
#
# "bibtexKey": "herppich1989camausprgung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e49d4de272be8c4d6003f87f7393566c/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Asteraceae","merged:rwst"
# ],
#
# "intraHash" : "e49d4de272be8c4d6003f87f7393566c",
# "interHash" : "7c932914a59db9d31e641fdf6bed9674",
# "label" : "Zur Kenntnis der Apogamie in der Gattung Hieracium",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:11",
# "count" : 1,
# "pub-type": "article",
# "journal": "Berichte der Deutsch. Botan. Gesellsch.",
# "year": "1904",
# "url": "",
#
# "author": [
# "C. Ostenfeld"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Ostenfeld"}
# ],
# "volume": "XXII","pages": "376",
# "bibtexKey": "O"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e612e5827e1797ee70bfd9a7af45bc2c/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "e612e5827e1797ee70bfd9a7af45bc2c",
# "interHash" : "b3332335d4814e15d8f7654dd35cbc24",
# "label" : "Der Einfluß von Phytohormonen (Auxin, Kinetin und Gibberellinsäure) auf den Photosyntheseapparat und den Nitrat-Stoffwechsel von Sinapis alba",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 09:28:59",
# "changeDate" : "2015-09-08 09:28:59",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1980",
# "url": "",
#
# "author": [
# "Rainer Zerbe"
# ],
# "authors": [
#
# {"first" : "Rainer",	"last" : "Zerbe"}
# ],
#
# "dnbtitleid" : "213069911",
#
# "bibtexKey": "zerbe1980einflu"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2ee8b361c206fd1154054611676dac11c/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Poaceae","merged:rwst"
# ],
#
# "intraHash" : "ee8b361c206fd1154054611676dac11c",
# "interHash" : "96922e82e1e7b17df30eb31aa9c1fe89",
# "label" : "Bastarde zwischen Maisrassen, mit besonderer Berücksichtigung der Xenien",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:10",
# "count" : 1,
# "pub-type": "article",
# "journal": "Bibliotheca botanica",
# "year": "1901",
# "url": "",
#
# "author": [
# "C. Correns"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Correns"}
# ],
# "number": "53",
# "bibtexKey": "c05"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2c4cc7f489abd860c6710218b05116786/genealogie",
# "tags" : [
# "Botanik","Naturwissenschaften","Physik","merged:genealogie","Pflanzen_Botanik","Paläontologie","Kartographie","Biowissenschaften","Chemie","Astronomie","dnb","Geowissenschaften","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "c4cc7f489abd860c6710218b05116786",
# "interHash" : "3dc4e5300d4f7f1b13f7da8c7a90438b",
# "label" : "Comparative analysis of light controlled growth in light and dark grown Sinapis alba L",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:31:56",
# "changeDate" : "2015-09-09 03:31:56",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Christopher John Beggs"
# ],
# "authors": [
#
# {"first" : "Christopher John",	"last" : "Beggs"}
# ],
#
# "dnbtitleid" : "810620030",
#
# "bibtexKey": "beggs1981comparative"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/252f025ae975dee0b57fbc427a606ad51/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "52f025ae975dee0b57fbc427a606ad51",
# "interHash" : "ef7302160f8a52bae9b132741705c570",
# "label" : "Der Entwicklungszyklus von Typhula incarnata Lasch ex Fr: feinstrukturelle u. funktionelle Aspekte",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:22:57",
# "changeDate" : "2015-09-09 05:22:57",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Berthold Metzler"
# ],
# "authors": [
#
# {"first" : "Berthold",	"last" : "Metzler"}
# ],
#
# "dnbtitleid" : "841061092",
#
# "bibtexKey": "metzler1984entwicklungszyklus"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/27c8b18c34201ec453f752564ecbdea88/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "7c8b18c34201ec453f752564ecbdea88",
# "interHash" : "e5616af222aff208e19bc7861eff2225",
# "label" : "Vergleichende Untersuchungen zur Entwicklung und Degeneration der Arbuskeln von Glomus fasciculatum (Thaxter sensu Gerd.) Gerd. & und Trappe (Endogonaceae) in den Wurzeln von Avena sativa L., Allium cepa L., Solanum lycopersicum L. und Phaseolus vulgaris L.",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:54:06",
# "changeDate" : "2015-09-09 07:54:06",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Tom Alexander"
# ],
# "authors": [
#
# {"first" : "Tom",	"last" : "Alexander"}
# ],
#
# "dnbtitleid" : "890292655",
#
# "bibtexKey": "alexander1987vergleichende"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/21a9b8e7a4fa10acf69d90927f0c28cc2/genealogie",
# "tags" : [
# "Jugendpflege","Erziehung","Schul_und_Bildungswesen","dnb","merged:genealogie","Unterricht"
# ],
#
# "intraHash" : "1a9b8e7a4fa10acf69d90927f0c28cc2",
# "interHash" : "b4e740ef51b3d1081ae68fb3099ab778",
# "label" : "Zur Erhöhung der Effektivität des Unterrichts bei der Einführung der Schüler in die Botanik",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 02:37:44",
# "changeDate" : "2015-09-09 02:37:44",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1977",
# "url": "",
#
# "author": [
# "Rainer Krohn"
# ],
# "authors": [
#
# {"first" : "Rainer",	"last" : "Krohn"}
# ],
#
# "dnbtitleid" : "790982943",
#
# "bibtexKey": "krohn1977erhhung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2430044de7ab929b0792ae773c1b5c8c7/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "430044de7ab929b0792ae773c1b5c8c7",
# "interHash" : "890fa8ac6a582bc133a371976a404cf6",
# "label" : "Der Briza-Komplex in Südamerika: Briza, Calotheca, Chascolytrum, Poidium (Gramineae): e. Revision",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 07:29:07",
# "changeDate" : "2015-09-08 07:29:07",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1972",
# "url": "",
#
# "author": [
# "Oscar Matthei"
# ],
# "authors": [
#
# {"first" : "Oscar",	"last" : "Matthei"}
# ],
#
# "dnbtitleid" : "208375333",
#
# "bibtexKey": "matthei1972brizakomplex"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2f8131403f490661d1b5d1c55d21e9519/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "f8131403f490661d1b5d1c55d21e9519",
# "interHash" : "978e82396c03b37895e9b0d1faf168e9",
# "label" : "Untersuchungen zur molekularen Grundlage von Resistenz im Weizen-Schwarzrost-System (Triticum spec. - Puccinia graminis f. sp. tritici)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:03:26",
# "changeDate" : "2015-09-09 06:03:26",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1985",
# "url": "",
#
# "author": [
# "Karl-Heinz Kogel"
# ],
# "authors": [
#
# {"first" : "Karl-Heinz",	"last" : "Kogel"}
# ],
#
# "dnbtitleid" : "860103242",
#
# "bibtexKey": "kogel1985untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/21b374fe6c4e2d83f199e6e79868775fb/genealogie",
# "tags" : [
# "dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "1b374fe6c4e2d83f199e6e79868775fb",
# "interHash" : "85af732ac2cbc2ac9ec432529490f91e",
# "label" : "Geschichte der Botanik in Jena von der Gründung der Universität bis zur Goethezeit",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-07 22:52:52",
# "changeDate" : "2015-09-07 22:52:52",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1963",
# "url": "",
#
# "author": [
# "Ilse Jahn"
# ],
# "authors": [
#
# {"first" : "Ilse",	"last" : "Jahn"}
# ],
#
# "editor": [
# "Nicolas Robin"
# ],
# "editors": [
#
# {"first" : "Nicolas",	"last" : "Robin"}
# ],
#
# "dnbtitleid" : "1009232959",
#
# "bibtexKey": "jahn1963geschichte"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/230138b7936cb1dd2f682b24980b4b896/genealogie",
# "tags" : [
# "Botanik","Naturwissenschaften","Physik","merged:genealogie","Pflanzen_Botanik","Paläontologie","Kartographie","Biowissenschaften","Chemie","Astronomie","dnb","Geowissenschaften","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "30138b7936cb1dd2f682b24980b4b896",
# "interHash" : "505bfab048c25b78f6a7be1ecfccb43c",
# "label" : "Reaktionen von Fontinalis antipyretica Hedw. nach experimentellen Belastungen mit Schwermetallverbindungen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:37:59",
# "changeDate" : "2015-09-09 03:37:59",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Curt Henrique Sommer"
# ],
# "authors": [
#
# {"first" : "Curt Henrique",	"last" : "Sommer"}
# ],
#
# "dnbtitleid" : "810819058",
#
# "bibtexKey": "sommer1981reaktionen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2fee081997fc9e148f03539e028a55271/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "fee081997fc9e148f03539e028a55271",
# "interHash" : "187aecb4cdda96171d5007322e8ba416",
# "label" : "Untersuchungen zu Aminosäurestoffwechsel und Nikkomycinbildung in Streptomyces tendae",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:20:10",
# "changeDate" : "2015-09-09 06:20:10",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Birgit Jordan"
# ],
# "authors": [
#
# {"first" : "Birgit",	"last" : "Jordan"}
# ],
#
# "dnbtitleid" : "860729850",
#
# "bibtexKey": "jordan1986untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/266c16acbab7031ffad28f54dd066e5df/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Umweltschutz","Landschaftsgestaltung","Raumordnung","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "66c16acbab7031ffad28f54dd066e5df",
# "interHash" : "5426e53909a764d88ffcd5f30d0de217",
# "label" : "Einfluss von Sulfit auf ausgewählte Bereiche des Aminosäurestoffwechsels bei der Flechtenalge Trebouxia spec",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:16:43",
# "changeDate" : "2015-09-09 04:16:43",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Dietrich Ewald"
# ],
# "authors": [
#
# {"first" : "Dietrich",	"last" : "Ewald"}
# ],
#
# "dnbtitleid" : "821140698",
#
# "bibtexKey": "ewald1982einfluss"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/26b0cc0d3ea322cc24d80d1ce9b446137/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Asteraceae","merged:rwst"
# ],
#
# "intraHash" : "6b0cc0d3ea322cc24d80d1ce9b446137",
# "interHash" : "81ed8f38d7e0aa65a86aa2ad8de0caac",
# "label" : "Kastrerings forsøg med Hieracium og andre Cichorieae",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:11",
# "count" : 1,
# "pub-type": "article",
# "journal": "Botanisk Tidsskrift",
# "year": "1903",
# "url": "",
#
# "author": [
# "C. Ostenfeld"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Ostenfeld"}
# ],
# "volume": "25",
# "bibtexKey": "OR"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25b2ed08af50507319f3399ce3949fb4b/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "5b2ed08af50507319f3399ce3949fb4b",
# "interHash" : "7f17108ef9c52c57ef13429563be0d34",
# "label" : "Zum Metabolismus der Indol-3-Essigsäure Indol-Essigsäure in gesunden und Rostpilz-infizierten Weizenblättern",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:37:45",
# "changeDate" : "2015-09-09 06:37:45",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Gertrud Wiese"
# ],
# "authors": [
#
# {"first" : "Gertrud",	"last" : "Wiese"}
# ],
#
# "dnbtitleid" : "870112449",
#
# "bibtexKey": "wiese1986metabolismus"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2abca9b751de03d8e75b706111082160f/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "abca9b751de03d8e75b706111082160f",
# "interHash" : "780af2577d2586f384b38de60099343a",
# "label" : "Zur Kontrolle der Fettsäure- und Glycerolipidsynthese isolierter Spinatchloroplasten",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:23:10",
# "changeDate" : "2015-09-09 05:23:10",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1983",
# "url": "",
#
# "author": [
# "Andreas Sauer"
# ],
# "authors": [
#
# {"first" : "Andreas",	"last" : "Sauer"}
# ],
#
# "dnbtitleid" : "841064946",
#
# "bibtexKey": "sauer1983kontrolle"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/26fb1d089bbf9596835c3b965053e8619/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "6fb1d089bbf9596835c3b965053e8619",
# "interHash" : "b5ca4d1c68ea56bb49189e3741d27482",
# "label" : "Untersuchungen zu Entwicklung und Eigenschaften von Lipasen und Glyoxysomen in reifenden und keimenden Ölsamen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 03:52:37",
# "changeDate" : "2015-09-09 03:52:37",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Anton Fusseder"
# ],
# "authors": [
#
# {"first" : "Anton",	"last" : "Fusseder"}
# ],
#
# "dnbtitleid" : "820209880",
#
# "bibtexKey": "fusseder1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/24f5c38fec605e03635d5a227cc5d51ed/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "4f5c38fec605e03635d5a227cc5d51ed",
# "interHash" : "60789a80bf10fcdfae864309cd02f0a2",
# "label" : "Systematische und ökologische Studien zur Bestandsaufnahme der Foraminiferenfauna um Helgoland in Abhängigkeit vom Jahresgang",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:16:44",
# "changeDate" : "2015-09-09 07:16:44",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Renate Küppers"
# ],
# "authors": [
#
# {"first" : "Renate",	"last" : "Küppers"}
# ],
#
# "dnbtitleid" : "880191740",
#
# "bibtexKey": "kuppers1987systematische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/281bf9600ad704187df595d0979465062/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "81bf9600ad704187df595d0979465062",
# "interHash" : "30b8f9368e99b0df4cbeecfa09ec1f42",
# "label" : "Charakterisierung und immuncytochemische Lokalisierung von Phosphorylase-Formen aus Spinat-Blättern",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:59:13",
# "changeDate" : "2015-09-09 04:59:13",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1983",
# "url": "",
#
# "author": [
# "Christoph Schächtele"
# ],
# "authors": [
#
# {"first" : "Christoph",	"last" : "Schächtele"}
# ],
#
# "dnbtitleid" : "840224559",
#
# "bibtexKey": "schachtele1983charakterisierung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2e29248561f5a0c19a811cb055a4e17d6/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "e29248561f5a0c19a811cb055a4e17d6",
# "interHash" : "cf3f8c0287233a27242f1d059099a581",
# "label" : "Einfluss eines verringerten Wasserpotentials bei verschiedenen Lichtintensitäten auf Wachstum und Akkumulation von Prolin und MDA bei Keimpflanzen von Hafer und Mais",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:01:22",
# "changeDate" : "2015-09-09 08:01:22",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Hanan Hamami"
# ],
# "authors": [
#
# {"first" : "Hanan",	"last" : "Hamami"}
# ],
#
# "dnbtitleid" : "890631913",
#
# "bibtexKey": "hamami1988einfluss"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/297269804b1653c137f2227c23a8c91ee/rwst",
# "tags" : [
# "Botanik","Genetik","Vor1950","Asteraceae","Biologie","merged:rwst"
# ],
#
# "intraHash" : "97269804b1653c137f2227c23a8c91ee",
# "interHash" : "e552347d3b771fc3cf6a746621f7bc14",
# "label" : "Weitere Beiträge zur Fruchtentwicklung bei der Gattung Hieracium",
# "user" : "rwst",
# "description" : "Bibliografie des Buchs Correns/Stephan: Mendels Briefe an Carl NÃ¤geli 1866-1873, BOD Norderstedt 2008. ISBN 3-83704176-X",
# "date" : "2009-08-02 16:40:10",
# "changeDate" : "2009-08-02 16:40:11",
# "count" : 1,
# "pub-type": "article",
# "journal": "Berichte der Deutsch. Botan. Gesellsch.",
# "year": "1904",
# "url": "",
#
# "author": [
# "C. Ostenfeld"
# ],
# "authors": [
#
# {"first" : "C.",	"last" : "Ostenfeld"}
# ],
# "volume": "XXII","pages": "537",
# "bibtexKey": "O1"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d18f481a27d8a71081410533226f403d/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "d18f481a27d8a71081410533226f403d",
# "interHash" : "67be2a3260d548314a3780de7b9e0225",
# "label" : "Entwicklung eines Testes mit bewurzelten Blättern von Solanum tuberosum L. zur Ermittlung von Aufnahme und Transport blattapplizierter Substanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 08:40:46",
# "changeDate" : "2015-09-09 08:40:46",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Gottfried Baier"
# ],
# "authors": [
#
# {"first" : "Gottfried",	"last" : "Baier"}
# ],
#
# "dnbtitleid" : "900074280",
#
# "bibtexKey": "baier1987entwicklung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/296d820657985c56dc3f86e378e92ea3b/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin"
# ],
#
# "intraHash" : "96d820657985c56dc3f86e378e92ea3b",
# "interHash" : "3d7d2268e99d224f0610fd13aeea1318",
# "label" : "Untersuchungen zum Vorkommen und zum Gehalt Wuchsstoff-ähnlicher Substanzen in verschiedenen Entwicklungsstadien der Kulturkarotte (Daucus carota L.)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:42:19",
# "changeDate" : "2015-09-09 04:42:19",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Klaus Palussek"
# ],
# "authors": [
#
# {"first" : "Klaus",	"last" : "Palussek"}
# ],
#
# "dnbtitleid" : "830833625",
#
# "bibtexKey": "palussek1982untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2501a79f6df067991725da4d87b2209ca/twiebke",
# "tags" : [
# "imported","merged:twiebke"
# ],
#
# "intraHash" : "501a79f6df067991725da4d87b2209ca",
# "interHash" : "7eae6ad2d14b070203cc86e5f0b4d137",
# "label" : "Skript zum Vertiefungsstudium Botanik/Forstnutzung, Einführung in\n\tdie Aboristik und Baumpflege für StudentInnen der Forstwissenschaften\n\tin Tharandt",
# "user" : "twiebke",
# "description" : "",
# "date" : "2012-01-19 14:03:07",
# "changeDate" : "2012-01-19 14:03:07",
# "count" : 1,
# "pub-type": "techreport",
#
# "year": "2004",
# "url": "",
#
# "author": [
# "Claus-Thomas Bues, Prof. Dr. Dr. habil."
# ],
# "authors": [
#
# {"first" : "Claus-Thomas",	"last" : "Bues, Prof. Dr. Dr. habil."}
# ],
#
# "owner" : "torsten",
#
# "bibtexKey": "Skript"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/26a09a976585bed7fdbf6b8b263b999db/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "6a09a976585bed7fdbf6b8b263b999db",
# "interHash" : "76a2b32fbfd9923759cd4ae4b7ceb4f6",
# "label" : "Manipulation individueller Zellen der Nutzpflanze Brassica napus L. mit Hilfe von Elektrofusion, Zellrekonstruktion und Mikroinjektion",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:19:21",
# "changeDate" : "2015-09-09 07:19:21",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Germán Spangenberg"
# ],
# "authors": [
#
# {"first" : "Germán",	"last" : "Spangenberg"}
# ],
#
# "dnbtitleid" : "880318171",
#
# "bibtexKey": "spangenberg1986manipulation"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2818732b67cd553bbfc52fa8d16302b32/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "818732b67cd553bbfc52fa8d16302b32",
# "interHash" : "7fec020f685109ab12c9e18852fa5c1b",
# "label" : "Nachweis und Charakterisierung durch Chalkonsynthase unter Verwendung definierter Genotypen höherer Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 09:30:51",
# "changeDate" : "2015-09-08 09:30:51",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Rgine Spribille","Regine Spribille"
# ],
# "authors": [
#
# {"first" : "Rgine",	"last" : "Spribille"},
# {"first" : "Regine",	"last" : "Spribille"}
# ],
#
# "dnbtitleid" : "213100746",
#
# "bibtexKey": "spribille1982nachweis"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2222400bed32696863265fb9dfd829521/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "222400bed32696863265fb9dfd829521",
# "interHash" : "2e17ad47a72e50612a06a85326d21a8d",
# "label" : "Biochemische Resistenzmechanismen von Sojabohne (Glycine max L.) gegenüber Phytophthora megasperma f.sp. glycinea",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:48:46",
# "changeDate" : "2015-09-09 07:48:46",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Anne Bonhoff"
# ],
# "authors": [
#
# {"first" : "Anne",	"last" : "Bonhoff"}
# ],
#
# ...
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:56:27",
# "changeDate" : "2015-09-09 05:56:27",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1985",
# "url": "",
#
# "author": [
# "Bernhard Eugen Nickl"
# ],
# "authors": [
#
# {"first" : "Bernhard Eugen",	"last" : "Nickl"}
# ],
#
# "dnbtitleid" : "850929172",
#
# "bibtexKey": "nickl1985steuerung"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/23fe5d19a2878ab00d6821f59492fdf25/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "3fe5d19a2878ab00d6821f59492fdf25",
# "interHash" : "5899b386c6d7ae417d9738b58b1eecf1",
# "label" : "Beiträge zur Taxonomie der Gattung Galinsoga R. et P. (Asteraceae, Heliantheae, Galinsoginae)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:44:49",
# "changeDate" : "2015-09-09 04:44:49",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Dorothea Schulz"
# ],
# "authors": [
#
# {"first" : "Dorothea",	"last" : "Schulz"}
# ],
#
# "dnbtitleid" : "830930078",
#
# "bibtexKey": "schulz1981beitrge"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2623462f3ca86d80afecc0e0d1f0a14b8/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "623462f3ca86d80afecc0e0d1f0a14b8",
# "interHash" : "b9fb15793637b9b8a50b82a3377a9fc3",
# "label" : "Untersuchungen zur Beteiligung von Ethylen und Gibberellinen an pflanzlichen Entwicklungsprozessen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 06:54:42",
# "changeDate" : "2015-09-09 06:54:42",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Daniela Kriechbaum"
# ],
# "authors": [
#
# {"first" : "Daniela",	"last" : "Kriechbaum"}
# ],
#
# "dnbtitleid" : "870813153",
#
# "bibtexKey": "kriechbaum1986untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2b3c5fa2162d14482e39b1bfcf703e7e7/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "b3c5fa2162d14482e39b1bfcf703e7e7",
# "interHash" : "06872f5438c60cd9a378e1b8c3d8056c",
# "label" : "Untersuchungen zur Mobilität von Xenobiotika in höheren Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:38:07",
# "changeDate" : "2015-09-09 04:38:07",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Stefanie Neumann"
# ],
# "authors": [
#
# {"first" : "Stefanie",	"last" : "Neumann"}
# ],
#
# "dnbtitleid" : "830669388",
#
# "bibtexKey": "neumann1982untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d05166e2c6beb03866be57a74d27011a/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "d05166e2c6beb03866be57a74d27011a",
# "interHash" : "de42db069554bbea46a46014bfe009de",
# "label" : "Zur Wirkungsweise von NOPflanzen: vergl. Untersuchungen im akuten u. chron. Bereich",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 08:55:53",
# "changeDate" : "2015-09-08 08:55:53",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Elke Boschke"
# ],
# "authors": [
#
# {"first" : "Elke",	"last" : "Boschke"}
# ],
#
# "dnbtitleid" : "212370510",
#
# "bibtexKey": "boschke1984wirkungsweise"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/294486a5c026d2431c048df159133dbf9/genealogie",
# "tags" : [
# "Garten","Biowissenschaften","Botanik","Landwirtschaft","Umweltschutz","Landschaftsgestaltung","Raumordnung","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "94486a5c026d2431c048df159133dbf9",
# "interHash" : "71402c54469912badf9e2ddf7bf98263",
# "label" : "Wasserhaushaltsparameter von Paprikafruchtzellen und die toxische Wirkung von Umweltchemikalien",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:51:20",
# "changeDate" : "2015-09-09 05:51:20",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Joachim Rygol"
# ],
# "authors": [
#
# {"first" : "Joachim",	"last" : "Rygol"}
# ],
#
# "dnbtitleid" : "850790670",
#
# "bibtexKey": "rygol1984wasserhaushaltsparameter"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2bcc643b6b7618d1c94bd276170592fd9/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "bcc643b6b7618d1c94bd276170592fd9",
# "interHash" : "f8405a606d5cc474706c79f0b390f1ff",
# "label" : "In-vitro-Regeneration der Erbse (Pisum sativum) über die somatische Embryogenese",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:50:07",
# "changeDate" : "2015-09-09 07:50:07",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Wilfried Kysely"
# ],
# "authors": [
#
# {"first" : "Wilfried",	"last" : "Kysely"}
# ],
#
# "dnbtitleid" : "890076251",
#
# "bibtexKey": "kysely1988invitroregeneration"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2726671b79dd9a502ab09d5bf65284a82/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "726671b79dd9a502ab09d5bf65284a82",
# "interHash" : "361c1e1d5288fb10ff1cc4b0b75bc343",
# "label" : "Zur Morphologie, Phylogenie und Systematik der Gattung Dalechampia L. (Euphorbiaceae): unter bes. Berücks. d. reproduktiv-pollinativen Bereiches",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 08:44:27",
# "changeDate" : "2015-09-08 08:44:27",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1986",
# "url": "",
#
# "author": [
# "Norbert Magin"
# ],
# "authors": [
#
# {"first" : "Norbert",	"last" : "Magin"}
# ],
#
# "dnbtitleid" : "212196561",
#
# "bibtexKey": "magin1986morphologie"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/288fda738e1ccf880042ebe1066ac0ce8/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "88fda738e1ccf880042ebe1066ac0ce8",
# "interHash" : "9bf9efdf19f02fe8051993767151d7af",
# "label" : "Biochemische Charakterisierung von Wildtypen, Mutanten und Fusionshybriden von Pichia guilliermondii",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:13:52",
# "changeDate" : "2015-09-09 04:13:52",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1982",
# "url": "",
#
# "author": [
# "Martina Hartung"
# ],
# "authors": [
#
# {"first" : "Martina",	"last" : "Hartung"}
# ],
#
# "dnbtitleid" : "821046837",
#
# "bibtexKey": "hartung1982biochemische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/215ab7263d3cff09b0d63c69c366af563/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "15ab7263d3cff09b0d63c69c366af563",
# "interHash" : "bd1cd7f1430dc70c890bb4ad23a5ea0b",
# "label" : "Die Wirkungen verschiedener Elicitoren und deren mögliche Bedeutung in Wirt/Pathogen-Beziehungen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:20:50",
# "changeDate" : "2015-09-09 05:20:50",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Harald Köhle"
# ],
# "authors": [
#
# {"first" : "Harald",	"last" : "Köhle"}
# ],
#
# "dnbtitleid" : "840998163",
#
# "bibtexKey": "kohle1984wirkungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/261d9a76f96775e12ca7a3832847d4ea4/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "61d9a76f96775e12ca7a3832847d4ea4",
# "interHash" : "7a79411facc145db7dfe2df69e81910b",
# "label" : "Vergleichende Untersuchungen über die Wirkung extremer Temperaturen auf Biomembranen von Blattzellen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:14:17",
# "changeDate" : "2015-09-09 05:14:17",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1983",
# "url": "",
#
# "author": [
# "Regina Thebud-Lassak"
# ],
# "authors": [
#
# {"first" : "Regina",	"last" : "Thebud-Lassak"}
# ],
#
# "dnbtitleid" : "840822146",
#
# "bibtexKey": "thebudlassak1983vergleichende"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/211f516d7b4b0828809c90b3b0b4a88da/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Umweltschutz","Landschaftsgestaltung","Raumordnung","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "11f516d7b4b0828809c90b3b0b4a88da",
# "interHash" : "13a0a1c3dc5841b2c5bbc5c2ebe5c2ed",
# "label" : "Untersuchungen über die Wirkung von Thallium auf die Primärprozesse der Photosynthese grüner Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:42:15",
# "changeDate" : "2015-09-09 05:42:15",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1984",
# "url": "",
#
# "author": [
# "Hans-Georg Wystrcil"
# ],
# "authors": [
#
# {"first" : "Hans-Georg",	"last" : "Wystrcil"}
# ],
#
# "dnbtitleid" : "850500516",
#
# "bibtexKey": "wystrcil1984untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2248825044d92fa577b4fa41d73a58943/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin"
# ],
#
# "intraHash" : "248825044d92fa577b4fa41d73a58943",
# "interHash" : "f8be861f362ae5cf724a62d1808fbd50",
# "label" : "Morphologische Analyse des Einflusses von Alar auf das Wachstum von Ackerbohnenpflanzen (Vicia faba L.)",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:02:57",
# "changeDate" : "2015-09-09 04:02:57",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Hilda Moreno Tapia"
# ],
# "authors": [
#
# {"first" : "Hilda",	"last" : "Moreno Tapia"}
# ],
#
# "dnbtitleid" : "820625833",
#
# "bibtexKey": "morenotapia1981morphologische"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/2d53417fcc26af1b075973d534718e0a8/genealogie",
# "tags" : [
# "Garten","Biowissenschaften","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Reisen","Biologie","Tiere_Zoologie","Geographie","Heimat_und_Länderkunde"
# ],
#
# "intraHash" : "d53417fcc26af1b075973d534718e0a8",
# "interHash" : "dd6b90c051d5c170931ed67a91620e6c",
# "label" : "Die Vegetation der Waldwege und ihre Korrelation zu den Waldgesellschaften in verschiedenen Landschaften Südwestdeutschlands",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:13:05",
# "changeDate" : "2015-09-09 07:13:05",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1987",
# "url": "",
#
# "author": [
# "Burkhard Schall"
# ],
# "authors": [
#
# {"first" : "Burkhard",	"last" : "Schall"}
# ],
#
# "dnbtitleid" : "880024860",
#
# "bibtexKey": "schall1987vegetation"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/21b098a1ef8c7d88bb40da2a33e5e5efc/rwst",
# "tags" : [
# "biology","plant-families","Asteraceae","botanik","botany","Europa","Biologie","Welt","merged:rwst"
# ],
#
# "intraHash" : "1b098a1ef8c7d88bb40da2a33e5e5efc",
# "interHash" : "9b4deb83a77e4e3e10dcd9da26db80e4",
# "label" : "Biodiversity and ecogeography of wild Lactuca spp in some European countries",
# "user" : "rwst",
# "description" : "",
# "date" : "2009-08-04 11:51:07",
# "changeDate" : "2009-08-04 11:51:07",
# "count" : 1,
# "pub-type": "article",
# "journal": "Genetic Resources and Crop Evolution",
# "year": "2001",
# "url": "",
#
# "author": [
# "A. Lebeda","I. Doležalovà","E. Křístková","B. Mieslerová"
# ],
# "authors": [
#
# {"first" : "A.",	"last" : "Lebeda"},
# {"first" : "I.",	"last" : "Doležalovà"},
# {"first" : "E.",	"last" : "Křístková"},
# {"first" : "B.",	"last" : "Mieslerová"}
# ],
# "volume": "48","pages": "153--64",
# "bibtexKey": "ldkm2000"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/280b73409d4c949604552045afa3a879b/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "80b73409d4c949604552045afa3a879b",
# "interHash" : "e376f3fba85ea024900b3fb413d9b4d6",
# "label" : "Untersuchungen zur Differenzierung von Agropyron repens (L.) Beauv",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 04:08:51",
# "changeDate" : "2015-09-09 04:08:51",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Franz Güttel"
# ],
# "authors": [
#
# {"first" : "Franz",	"last" : "Güttel"}
# ],
#
# "dnbtitleid" : "820863513",
#
# "bibtexKey": "guttel1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/280856cdedd6f0adee7a62c426c1bcf6b/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","Chemie","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "80856cdedd6f0adee7a62c426c1bcf6b",
# "interHash" : "6a7e9bd78cb9830500d7728b698847e2",
# "label" : "Einfluss von NaCl auf Wachstum und Stoffwechsel verschieden salztoleranter Pflanzen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 10:24:11",
# "changeDate" : "2015-09-09 10:24:11",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1977",
# "url": "",
#
# "author": [
# "Albrecht Priebe"
# ],
# "authors": [
#
# {"first" : "Albrecht",	"last" : "Priebe"}
# ],
#
# "dnbtitleid" : "920258239",
#
# "bibtexKey": "priebe1977einfluss"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/286ed86852467b83cbcb040fa7cd8e006/genealogie",
# "tags" : [
# "Garten","Botanik","Landwirtschaft","dnb","merged:genealogie","Pflanzen_Botanik","Veterinärmedizin","Biologie"
# ],
#
# "intraHash" : "86ed86852467b83cbcb040fa7cd8e006",
# "interHash" : "96c3681a625be96f4773de736cf06c0b",
# "label" : "Untersuchungen zur Bedeutung des Indol-3-Methylglucosinolat Metabolismus Indol-Methylglucosinolat-Metabolismus für die Indol-3-Essigsäure Biosynthese Indol-Essigsäure-Biosynthese in Plasmodiophora-brassicae-infiziertem Wurzelgewebe von Cruciferen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 05:24:36",
# "changeDate" : "2015-09-09 05:24:36",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1981",
# "url": "",
#
# "author": [
# "Thomas Rausch"
# ],
# "authors": [
#
# {"first" : "Thomas",	"last" : "Rausch"}
# ],
#
# "dnbtitleid" : "841091005",
#
# "bibtexKey": "rausch1981untersuchungen"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/25c713bbb4bc55e35b877a1d06584e794/genealogie",
# "tags" : [
# "Biowissenschaften","Botanik","dnb","merged:genealogie","Pflanzen_Botanik","Biologie","Tiere_Zoologie"
# ],
#
# "intraHash" : "5c713bbb4bc55e35b877a1d06584e794",
# "interHash" : "6e9ebc1bc26eb6ecae0c630d57435d16",
# "label" : "Der Vegetationskomplex der Sandtrockenrasen in der Westfälischen Bucht",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-09 07:39:27",
# "changeDate" : "2015-09-09 07:39:27",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1988",
# "url": "",
#
# "author": [
# "Eckhard Schröder"
# ],
# "authors": [
#
# {"first" : "Eckhard",	"last" : "Schröder"}
# ],
#
# "dnbtitleid" : "881168688",
#
# "bibtexKey": "schroder1988vegetationskomplex"
#
# }
# ,
# {
# "type" : "Publication",
# "id"   : "https://www.bibsonomy.org/bibtex/24097b4a6a5cfb1e3fae61ff0c06d88bd/genealogie",
# "tags" : [
# "Botanik","dnb","merged:genealogie","Pflanzen_Botanik"
# ],
#
# "intraHash" : "4097b4a6a5cfb1e3fae61ff0c06d88bd",
# "interHash" : "03f9c879dd632651e584af2bd43db15d",
# "label" : "Der weibliche Zapfen von Pseudovoltzia liebeana und seine Bedeutung für die Phylogenie der Koniferen",
# "user" : "genealogie",
# "description" : "",
# "date" : "2015-09-08 09:43:01",
# "changeDate" : "2015-09-08 09:43:01",
# "count" : 1,
# "pub-type": "phdthesis",
#
# "year": "1966",
# "url": "",
#
# "author": [
# "Hans-Joachim Schweitzer"
# ],
# "authors": [
#
# {"first" : "Hans-Joachim",	"last" : "Schweitzer"}
# ],
#
# "dnbtitleid" : "213185458",
#
# "bibtexKey": "schweitzer1966weibliche"
#
# }
#
# ]
# }

# %%
type(data)
# Out:
# list
